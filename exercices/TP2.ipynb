# %% [markdown]
# ## Objectifs
# ##### 1 Lire et traiter des données d'entrée avec [PANDAS](https://pandas.pydata.org/)
#
# ##### 2 Représenter la distribution empirique des "fold-change" (**FC**) vs Précision, aka: volcano-plot
#
# ##### 3 Effectuer une analyse de sur-représentation en termes GO
#
#
# ## Ressources : Rappels et illustration de l'analyse de représentation de termes GO
# ###### [TP de MADP](https://github.com/glaunay/tp-proteomics#3-obtention-des-param%C3%A8tres-du-mod%C3%A8le)
# ###### [Fiche Bioconductor](https://www.bioconductor.org/help/course-materials/2015/SeattleApr2015/E_GeneSetEnrichment.html)

# %% [markdown]
# ### Préparation de  l'environnement
#
# ##### Please `pip install -r requirements.txt` first
#
# ##### Directory Configuration
#
# * `workDir` points to the Git project, holds the *tsv* file
# * `libDir` points to Git project subdirectory hosting python library with files names `go.py  stat_utils.py  uniprot.py`
# * `dataDir` points to the data folder with uniprot and GO files

# %%
import sys, os
workDir = f"{os.getcwd()}/.."
libDir = f"{workDir}/lib"
dataDir= f"{workDir}/data" 

sys.path.append(libDir)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %% [markdown]
# ## Jeux de données
# * Jeux de données de protéomique quantitative au format TSV
# * Ontologie GO au format [owl](http://www.obofoundry.org/ontology/go.html)
# * Entrées Uniprot au format XML
#     * Protéines de l'étude
#     * Protéome d'E.Coli complet
#
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ### Lecture des valeurs experimentales
# Charger ```TCL_wt1.tsv``` dans une [dataframe pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$
# Retirer les lignes présentant des aberrations numériques
# </span>
# <br/><span style="color:firebrick;font-weight:bold">$\rhd$ Attention aux types des colonnes !</span>

# %%
data = pd.read_csv("../TCL_wt1.tsv", sep="\t",  dtype={'Corrected Abundance ratio (1.53)':np.float64, 'Log2 Corrected Abundance Ratio':np.float64, 'Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)':np.float64, 'LOG10 Adj.P-val':np.float64}, na_values='#VALEUR!').dropna()
data
# Out:
#      Accession                                        Description Gene Symbol  \
# 0       P75936  Basal-body rod modification protein FlgD OS=Es...        flgD
# 1       P76231  Uncharacterized protein YeaC OS=Escherichia co...        yeaC
# 2       P0A8S9  Flagellar transcriptional regulator FlhD OS=Es...        flhD
# 4       P05706  PTS system glucitol/sorbitol-specific EIIA com...        srlB
# 5       P29744  Flagellar hook-associated protein 3 OS=Escheri...        flgL
# ...        ...                                                ...         ...
# 2011    P77330  Prophage lipoprotein Bor homolog OS=Escherichi...        borD
# 2016    P02930  Outer membrane protein TolC OS=Escherichia col...        tolC
# 2020    P0A917  Outer membrane protein X OS=Escherichia coli (...        ompX
# 2021    P02931  Outer membrane protein F OS=Escherichia coli (...        ompF
# 2022    P0AB40  Multiple stress resistance protein BhsA OS=Esc...        bhsA
#
#       Corrected Abundance ratio (1.53)  Log2 Corrected Abundance Ratio  \
# 0                             0.075817                       -3.721335
# 1                             0.092810                       -3.429569
# 2                             0.102614                       -3.284695
# 4                             0.108497                       -3.204277
# 5                             0.124183                       -3.009460
# ...                                ...                             ...
# 2011                          1.535948                        0.619129
# 2016                          1.552288                        0.634396
# 2020                          1.579739                        0.659686
# 2021                          1.754902                        0.811390
# 2022                          1.798039                        0.846424
#
#       Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)  \
# 0                                              0.000055
# 1                                              0.000351
# 2                                              0.000027
# 4                                              0.019963
# 5                                              0.036746
# ...                                                 ...
# 2011                                           0.310725
# 2016                                           0.013373
# 2020                                           0.002226
# 2021                                           0.000068
# 2022                                           0.035928
#
#       LOG10 Adj.P-val
# 0            4.260067
# 1            3.454627
# 2            4.571899
# 4            1.699768
# 5            1.434787
# ...               ...
# 2011         0.507623
# 2016         1.873757
# 2020         2.652391
# 2021         4.164956
# 2022         1.444561
#
# [1746 rows x 7 columns]

# %% [markdown]
# ##### 1. Un premier volcano-plot
#
# Ce type de figure représente pour chaque protéine en abscisse le taux d'abondance et en ordonnée la précision de la mesure.
#
# <span style="color:firebrick;font-weight:bold">$\rhd$ 1. Réaliser un scatter plot matplotlib avec</span>
# <br/><span style="color:firebrick;font-weight:bold">- en x, `Log2 Corrected Abundance Ratio`</span>
# <br/><span style="color:firebrick;font-weight:bold">-  en y, `LOG10 Adj.P-val`</span>
#
# <span style="color:firebrick;font-weight:bold">$\rhd$Vous légenderez les axes, attention `LOG10 Adj.P-val` est en fait `-LOG10 Adj.P-val`, regardez bien.</span>

# %% [markdown]
# ##### 2. Réaliser des versions évoluées du graphique précédent
# L'objectif est de mettre l'accent sur la région **-Log10 adj Pvalue > 4** et **Log2 corrected abundance ratio > 0**.
# <br/>Pour cela vous revisiterez le scatter plot précedent au travers des versions suivantes:
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ première version : un rectangle de la couleur de votre choix matérialisera la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ deuxième version  : une couleur de votre choix représentera les points de la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ troisème version (optionnel): Les identifiants uniprot remplaceront les points des protéines de la région</span>

# %%
fig1,ax1 = plt.subplots(dpi=150)
ax1.scatter(data["Log2 Corrected Abundance Ratio"], data["LOG10 Adj.P-val"])
rect1 = matplotlib.patches.Rectangle((0,4),10,10, color="red", alpha=0.5)
ax1.add_patch(rect1)
plt.ylabel("-LOG10 Adj.P-val")
plt.xlabel("Taux d'abondance")
plt.xlim([-4, 2])
plt.ylim([0, 9])
plt.show()

# %%
fig1,ax1 = plt.subplots(dpi=150)
x = data["Log2 Corrected Abundance Ratio"]
y = data["LOG10 Adj.P-val"]
col = np.where(x>0,np.where(y>4,'r','b'),'b')
ax1.scatter(x,y,color=col)
plt.ylabel("-LOG10 Adj.P-val")
plt.xlabel("Taux d'abondance")
plt.show()

# %%
from adjustText import adjust_text # Evite les labels superposés

# %%
fig1,ax1 = plt.subplots(dpi=150)
x = data["Log2 Corrected Abundance Ratio"]
y = data["LOG10 Adj.P-val"]

n = data["Accession"]
col = np.where(x>0,np.where(y>4,'w','b'),'b')
texte = []
ax1.scatter(x,y, color=col)
for i, txt in enumerate(n):
    if x.iloc[i] > 0 and y.iloc[i] > 4:
        texte += [ax1.text(x.iloc[i], y.iloc[i],txt)]
        
        #ax1.annotate(txt, (x.iloc[i],y.iloc[i]), arrowprops=dict(facecolor="black", shrink=0.01))
plt.ylabel("-LOG10 Adj.P-val")
plt.xlabel("Taux d'abondance")
adjust_text(texte)
plt.show()

# %% [markdown]
# #### Analyse ORA
#
# ##### Principes
# Vous disposez d'un objet analyser permettant de réaliser une analyse de la sur-représentation (**ORA**) en termes GO parmi une liste de protéine d'intérêt.
# La fréquence des termes GO dans le protéome totale est utilisée comme référence.
#
# L'objet analyser s'instancie ainsi
# ```python
# from stat_utils import GO_ORA_analyser
# o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# ```
#
# Il fournit une méthode pour chaque catégorie de termes GO
# <i>{ biological_process, molecular_function, cellular_component }</i>
#
# Une éventuelle surreprésentation des termes GO de la catégorie <i>biological_process</i> est par exemple calculée parmi les protéines P29744 et P05706 de la façon suivante:
#
# ```python
# goTerm_scores = o.biological_process(["P29744", "P05706"])
# ```
# <span style="color:green;font-weight:bold">$\uparrow$ Reproduire cet exemple dans la cellule ci-dessous.$\downarrow$ </span>
# </br><span style="color:firebrick;font-weight:bold"> $\rhd$ Inspecter l'objet retourné par la méthode o.biological_process, que voyez-vous ?</span>

# %%
from stat_utils import GO_ORA_analyser
o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# Loading ontology
# Loaded
# Reading whole proteome
# 4391 Loaded
# reading experimental protein set
# 2024 Loaded

# %%
goTerm_scores = o.biological_process(["P29744", "P05706"])
# Out:
# Building biological process GO Tree
# Extracting biological process ontology
# Applying true path collapsing
# 8 GO terms, 2 leaves, 2 proteins
# Extracting biological process ontology
# Applying true path collapsing
# 2728 GO terms, 6650 leaves, 3128 proteins
# Evaluated 7 / 7 Pathways, based on 2 proteins

# %%
o.biological_process(["P29744", "P05706"])
# Out:
# Evaluated 7 / 7 Pathways, based on 2 proteins
# [(0.03359505459608731,
#   'bacterial-type flagellum-dependent cell motility',
#   'GO:0071973',
#   ['P29744']),
#  (0.03485155369421565,
#   'archaeal or bacterial-type flagellum-dependent cell motility',
#   'GO:0097588',
#   ['P29744']),
#  (0.03673476977587685,
#   'phosphoenolpyruvate-dependent sugar phosphotransferase system',
#   'GO:0009401',
#   ['P05706']),
#  (0.037989225453758504, 'cell motility', 'GO:0048870', ['P29744']),
#  (0.04312840804885229, 'localization', 'GO:0051179', ['P29744', 'P05706']),
#  (1.0, 'biological_process', 'GO:0008150', ['P29744', 'P05706'])]

# %%
type(goTerm_scores)
# Out:
# list

# %% [markdown]
# ###### 2/ Analyser la représentation des termes GO parmi les protéines surabondantes de l'experience
# <span style="color:firebrick;font-weight:bold"> $\rhd$ Vous devrez extraire les identifiants uniprot des protéines aux `Log2 Corrected Abundance Ratio` supérieurs au seuil alpha de 5%.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous conduirez sur cette liste de protéines une analyse de sur-représentation en termes GO à l'aide d'un objet *GO_ORA_analyser*.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous pouvez faire varier le seuil d'abondance autour de la valeur alpha.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous traiterez les 3 catégories *biological_process / molecular_function /cellular_component*.</span>
#
#
#
# Familiarisez-vous avec la structures des dictionnaires de résultas, vous pouvez [les sauvegarder au format json](https://docs.python.org/3/library/json.html).

# %%
data_alpha = data[data["Log2 Corrected Abundance Ratio"] > np.log2(0.05)]
data_alpha["Accession"]
# Out:
# 0       P75936
# 1       P76231
# 2       P0A8S9
# 4       P05706
# 5       P29744
#          ...
# 2011    P77330
# 2016    P02930
# 2020    P0A917
# 2021    P02931
# 2022    P0AB40
# Name: Accession, Length: 1746, dtype: object

# %%
GO_term = {
    "biological_process" : [],
    "molecular_function" : [],
    "cellular_component" : []
}
list_prot = []
for prot in data_alpha["Accession"]:
        list_prot += {prot}
GO_term["biological_process"] = o.biological_process(list_prot)
GO_term["molecular_function"] = o.molecular_function(list_prot)
GO_term["cellular_component"] = o.cellular_component(list_prot)
# Out:
# Evaluated 7 / 7 Pathways, based on 1746 proteins
# molecular function process GO Tree
# Extracting molecular function ontology
# Applying true path collapsing
# 1692 GO terms, 4321 leaves, 1514 proteins
# Extracting molecular function ontology
# Applying true path collapsing
# 2264 GO terms, 7807 leaves, 3118 proteins
# Evaluated 1691 / 1691 Pathways, based on 1746 proteins
# cellular component process GO Tree
# Extracting cellular component ontology
# Applying true path collapsing
# 209 GO terms, 2320 leaves, 1423 proteins
# Extracting cellular component ontology
# Applying true path collapsing
# 239 GO terms, 4698 leaves, 2805 proteins
# Evaluated 208 / 208 Pathways, based on 1746 proteins

# %%
GO_term
# Out:
# {'biological_process': [(0.9999999999342061,
#    'bacterial-type flagellum-dependent cell motility',
#    'GO:0071973',
#    ['P29744']),
#   (0.9999999999698048,
#    'archaeal or bacterial-type flagellum-dependent cell motility',
#    'GO:0097588',
#    ['P29744']),
#   (0.9999999999862025,
#    'phosphoenolpyruvate-dependent sugar phosphotransferase system',
#    'GO:0009401',
#    ['P05706']),
#   (0.9999999999883546, 'cell motility', 'GO:0048870', ['P29744']),
#   (0.9999999999942798, 'localization', 'GO:0051179', ['P29744', 'P05706']),
#   (1.0, 'biological_process', 'GO:0008150', ['P29744', 'P05706'])],
#  'molecular_function': [(7.601006048565208e-05,
#    'identical protein binding',
#    'GO:0042802',
#    ['P0C054',
#     'P0AGK8',
#     'P04982',
#     'P0AFP6',
#     'P0A759',
#     'Q46938',
#     'P0AFG3',
#     'P0C058',
#     'P0A8L1',
#     'P0A9S3',
#     'P0A794',
#     'P0AET8',
#     'P17445',
#     'P07004',
#     'P12758',
#     'P0A722',
#     'P06993',
#     'P0ABP8',
#     'P0AC16',
#     'P0A853',
#     'P0ABD3',
#     'P69922',
#     'P0A7J0',
#     'P0A9C5',
#     'P04128',
#     'P25553',
#     'P0AB80',
#     'P0A9H9',
#     'P0AGG2',
#     'P0AF03',
#     'P0AEU7',
#     'P15034',
#     'P0AEZ9',
#     'P33195',
#     'P21179',
#     'P0AEE3',
#     'P0A6L4',
#     'P0A6F5',
#     'P07003',
#     'P0A9P0',
#     'P31057',
#     'P38134',
#     'P21513',
#     'P0ABU7',
#     'P13029',
#     'P46889',
#     'P39377',
#     'P0ABV2',
#     'P0ACD4',
#     'P0A9Q7',
#     'P00957',
#     'P0A998',
#     'P0ACC7',
#     'P10408',
#     'P0AG18',
#     'P05055',
#     'P21367',
#     'P37095',
#     'P04036',
#     'P00805',
#     'P25524',
#     'P22523',
#     'P06987',
#     'P0A796',
#     'P12008',
#     'P0ADG7',
#     'P0A8F8',
#     'P0A698',
#     'P05793',
#     'P0A6T1',
#     'P75823',
#     'P0AAB4',
#     'P0AES9',
#     'P0ABT2',
#     'P00350',
#     'P50466',
#     'P0AG16',
#     'P0A6X1',
#     'P0AFG8',
#     'P0ABD5',
#     'P0A6H1',
#     'P37773',
#     'P07395',
#     'P03004',
#     'P0AFL6',
#     'P76291',
#     'P21645',
#     'P0A6Q6',
#     'P0ABH7',
#     'P0AEK4',
#     'P0AG30',
#     'P52612',
#     'P0AES4',
#     'P04825',
#     'P05707',
#     'P06136',
#     'P0A6G7',
#     'P0A6I6',
#     'P03023',
#     'P0A7B8',
#     'P0A9A6',
#     'P31069',
#     'P33650',
#     'P0A6E4',
#     'P06710',
#     'P0A817',
#     'P31224',
#     'P00452',
#     'P60785',
#     'P77791',
#     'P0AEJ4',
#     'P0A6V1',
#     'P0A7E9',
#     'P0AE82',
#     'P0AGE0',
#     'P31663',
#     'P23909',
#     'P0AD61',
#     'P0A6L2',
#     'P0A988',
#     'P0A894',
#     'Q46893',
#     'P0ADV9',
#     'P37194',
#     'P21599',
#     'P75682',
#     'P0A8J2',
#     'P0AC53',
#     'P31473',
#     'P37353',
#     'P0ABZ1',
#     'P0A951',
#     'P0ACU0',
#     'P0A7C2',
#     'P0AB71',
#     'P76423',
#     'P0AE06',
#     'P45568',
#     'P76491',
#     'P69425',
#     'P0ABH0',
#     'P39099',
#     'P23837',
#     'P0AC33',
#     'P09546',
#     'P03024',
#     'P0AFX9',
#     'P0C093',
#     'P0A742',
#     'P60546',
#     'P52097',
#     'P0A6S5',
#     'P0C0S1',
#     'P69924',
#     'P50456',
#     'P19624',
#     'P60752',
#     'P22106',
#     'P0ADA1',
#     'P0ACB0',
#     'P24203',
#     'P0ADI4',
#     'P63284',
#     'P0AFM6',
#     'P15047',
#     'P0A6Y5',
#     'P69503',
#     'P0A879',
#     'P0A9W9',
#     'P40710',
#     'P00963',
#     'P0ADS2',
#     'P0A734',
#     'P39376',
#     'P18196',
#     'P0AF93',
#     'P77150',
#     'P33025',
#     'P0AC51',
#     'P69423',
#     'P0AEP3',
#     'P0A962',
#     'P04079',
#     'P00509',
#     'P0A9S5',
#     'P06986',
#     'P14900',
#     'P05194',
#     'P0A825',
#     'P76541',
#     'P76015',
#     'P0AB91',
#     'P0A8G6',
#     'P0ACN4',
#     'P43671',
#     'P0A873',
#     'P75831',
#     'P0C0V0',
#     'P0A6Z3',
#     'P25522',
#     'P0ACJ0',
#     'P60560',
#     'P63284-2',
#     'P69931',
#     'P0AD57',
#     'P0AEZ3',
#     'P06999',
#     'P69428',
#     'P0A6H5',
#     'P0ADV1',
#     'P0A7E5',
#     'P0ADY1',
#     'P0AB10',
#     'P36680',
#     'P0AED7',
#     'P0ABF6',
#     'P0A7B5',
#     'P37744',
#     'P00887',
#     'P0ACF0',
#     'P27306',
#     'P25437',
#     'P66817',
#     'P65870',
#     'P0AC92',
#     'P09147',
#     'P38489',
#     'P30014',
#     'P27828',
#     'P0A6P9',
#     'P0AF36',
#     'P0A9T0',
#     'P0ACF4',
#     'P77804',
#     'P0A6F9',
#     'P0A858',
#     'P69228',
#     'P27303',
#     'P25536',
#     'P08839',
#     'P69776',
#     'P27833',
#     'P0A9L3',
#     'P0A6F3',
#     'P37759',
#     'P23893',
#     'P0A9F3',
#     'P76256',
#     'P0A850',
#     'P0A7Z0',
#     'P0A955',
#     'P33920',
#     'P12281',
#     'P05852',
#     'P0A6D0',
#     'P0ACJ8',
#     'P67095',
#     'P23836',
#     'P0AF12',
#     'P62617',
#     'P0A9X4',
#     'P0AF67',
#     'P0ACA7',
#     'P0AE08',
#     'P0AFY8',
#     'P0ABK5',
#     'P0A9Z1',
#     'P0A8F0',
#     'P0AED0',
#     'P0A9Q1',
#     'P0AB52',
#     'P0AFJ5',
#     'P0AEK2',
#     'P0A903',
#     'P77774',
#     'P0ACF8',
#     'P0A937',
#     'P0A9L8',
#     'P0A910',
#     'P02930',
#     'P02931',
#     'P00350',
#     'P0AFG8',
#     'P09372',
#     'P0A6E4',
#     'P0AE70',
#     'P0A6R3',
#     'P0A9K7',
#     'P06709',
#     'P0AFZ3',
#     'P05704',
#     'P0A8I8',
#     'P07017',
#     'P52061',
#     'P33644',
#     'P02942',
#     'P0AFI7',
#     'P0A921',
#     'P0A7K2']),
#   (0.00012670434614784154,
#    'protein binding',
#    'GO:0005515',
#    ['P0ABR1',
#     'P0A8R0',
#     'P0AF90',
#     'P0AB38',
#     'P0A7Y0',
#     'P0AFW4',
#     'P0A6W5',
#     'P30128',
#     'P30958',
#     'P13445',
#     'P60240',
#     'P0AFF6',
#     'P0AFW0',
#     'P21513',
#     'P0A6H1',
#     'P0A6G7',
#     'P0AFZ3',
#     'P07017',
#     'P02942',
#     'P0A6P1',
#     'P0C054',
#     'P0AGK8',
#     'P04982',
#     'P0AFP6',
#     'P0A759',
#     'Q46938',
#     'P0AFG3',
#     'P0C058',
#     'P0A8L1',
#     'P0A9S3',
#     'P0A794',
#     'P0AET8',
#     'P17445',
#     'P07004',
#     'P12758',
#     'P0A722',
#     'P06993',
#     'P0ABP8',
#     'P0AC16',
#     'P0A853',
#     'P0ABD3',
#     'P69922',
#     'P0A7J0',
#     'P0A9C5',
#     'P04128',
#     'P25553',
#     'P0AB80',
#     'P0A9H9',
#     'P0AGG2',
#     'P0AF03',
#     'P0AEU7',
#     'P15034',
#     'P0AEZ9',
#     'P33195',
#     'P21179',
#     'P0AEE3',
#     'P0A6L4',
#     'P0A6F5',
#     'P07003',
#     'P0A9P0',
#     'P31057',
#     'P38134',
#     'P21513',
#     'P0ABU7',
#     'P13029',
#     'P46889',
#     'P39377',
#     'P0ABV2',
#     'P0ACD4',
#     'P0A9Q7',
#     'P00957',
#     'P0A998',
#     'P0ACC7',
#     'P10408',
#     'P0AG18',
#     'P05055',
#     'P21367',
#     'P37095',
#     'P04036',
#     'P00805',
#     'P25524',
#     'P22523',
#     'P06987',
#     'P0A796',
#     'P12008',
#     'P0ADG7',
#     'P0A8F8',
#     'P0A698',
#     'P05793',
#     'P0A6T1',
#     'P75823',
#     'P0AAB4',
#     'P0AES9',
#     'P0ABT2',
#     'P00350',
#     'P50466',
#     'P0AG16',
#     'P0A6X1',
#     'P0AFG8',
#     'P0ABD5',
#     'P0A6H1',
#     'P37773',
#     'P07395',
#     'P03004',
#     'P0AFL6',
#     'P76291',
#     'P21645',
#     'P0A6Q6',
#     'P0ABH7',
#     'P0AEK4',
#     'P0AG30',
#     'P52612',
#     'P0AES4',
#     'P04825',
#     'P05707',
#     'P06136',
#     'P0A6G7',
#     'P0A6I6',
#     'P03023',
#     'P0A7B8',
#     'P0A9A6',
#     'P31069',
#     'P33650',
#     'P0A6E4',
#     'P06710',
#     'P0A817',
#     'P31224',
#     'P00452',
#     'P60785',
#     'P77791',
#     'P0AEJ4',
#     'P0A6V1',
#     'P0A7E9',
#     'P0AE82',
#     'P0AGE0',
#     'P31663',
#     'P23909',
#     'P0AD61',
#     'P0A6L2',
#     'P0A988',
#     'P0A894',
#     'Q46893',
#     'P0ADV9',
#     'P37194',
#     'P21599',
#     'P75682',
#     'P0A8J2',
#     'P0AC53',
#     'P31473',
#     'P37353',
#     'P0ABZ1',
#     'P0A951',
#     'P0ACU0',
#     'P0A7C2',
#     'P0AB71',
#     'P76423',
#     'P0AE06',
#     'P45568',
#     'P76491',
#     'P69425',
#     'P0ABH0',
#     'P39099',
#     'P23837',
#     'P0AC33',
#     'P09546',
#     'P03024',
#     'P0AFX9',
#     'P0C093',
#     'P0A742',
#     'P60546',
#     'P52097',
#     'P0A6S5',
#     'P0C0S1',
#     'P69924',
#     'P50456',
#     'P19624',
#     'P60752',
#     'P22106',
#     'P0ADA1',
#     'P0ACB0',
#     'P24203',
#     'P0ADI4',
#     'P63284',
#     'P0AFM6',
#     'P15047',
#     'P0A6Y5',
#     'P69503',
#     'P0A879',
#     'P0A9W9',
#     'P40710',
#     'P00963',
#     'P0ADS2',
#     'P0A734',
#     'P39376',
#     'P18196',
#     'P0AF93',
#     'P77150',
#     'P33025',
#     'P0AC51',
#     'P69423',
#     'P0AEP3',
#     'P0A962',
#     'P04079',
#     'P00509',
#     'P0A9S5',
#     'P06986',
#     'P14900',
#     'P05194',
#     'P0A825',
#     'P76541',
#     'P76015',
#     'P0AB91',
#     'P0A8G6',
#     'P0ACN4',
#     'P43671',
#     'P0A873',
#     'P75831',
#     'P0C0V0',
#     'P0A6Z3',
#     'P25522',
#     'P0ACJ0',
#     'P60560',
#     'P63284-2',
#     'P69931',
#     'P0AD57',
#     'P0AEZ3',
#     'P06999',
#     'P69428',
#     'P0A6H5',
#     'P0ADV1',
#     'P0A7E5',
#     'P0ADY1',
#     'P0AB10',
#     'P36680',
#     'P0AED7',
#     'P0ABF6',
#     'P0A7B5',
#     'P37744',
#     'P00887',
#     'P0ACF0',
#     'P27306',
#     'P25437',
#     'P66817',
#     'P65870',
#     'P0AC92',
#     'P09147',
#     'P38489',
#     'P30014',
#     'P27828',
#     'P0A6P9',
#     'P0AF36',
#     'P0A9T0',
#     'P0ACF4',
#     'P77804',
#     'P0A6F9',
#     'P0A858',
#     'P69228',
#     'P27303',
#     'P25536',
#     'P08839',
#     'P69776',
#     'P27833',
#     'P0A9L3',
#     'P0A6F3',
#     'P37759',
#     'P23893',
#     'P0A9F3',
#     'P76256',
#     'P0A850',
#     'P0A7Z0',
#     'P0A955',
#     'P33920',
#     'P12281',
#     'P05852',
#     'P0A6D0',
#     'P0ACJ8',
#     'P67095',
#     'P23836',
#     'P0AF12',
#     'P62617',
#     'P0A9X4',
#     'P0AF67',
#     'P0ACA7',
#     'P0AE08',
#     'P0AFY8',
#     'P0ABK5',
#     'P0A9Z1',
#     'P0A8F0',
#     'P0AED0',
#     'P0A9Q1',
#     'P0AB52',
#     'P0AFJ5',
#     'P0AEK2',
#     'P0A903',
#     'P77774',
#     'P0ACF8',
#     'P0A937',
#     'P0A9L8',
#     'P0A910',
#     'P02930',
#     'P02931',
#     'P00350',
#     'P0AFG8',
#     'P09372',
#     'P0A6E4',
#     'P0AE70',
#     'P0A6R3',
#     'P0A9K7',
#     'P06709',
#     'P0AFZ3',
#     'P05704',
#     'P0A8I8',
#     'P07017',
#     'P52061',
#     'P33644',
#     'P02942',
#     'P0AFI7',
#     'P0A921',
#     'P0A7K2',
#     'P0AEU7',
#     'P0A6F5',
#     'P0A6H1',
#     'P08622',
#     'P77754',
#     'P0AET2',
#     'P36659',
#     'P0A6Y8',
#     'P0AG86',
#     'P0A6Y5',
#     'P0A9K9',
#     'P0AF93',
#     'P0ABZ6',
#     'P0A6Z3',
#     'P0A6Z1',
#     'P09372',
#     'P0A964',
#     'P0A7B8',
#     'P0A855',
#     'P0A6H5',
#     'P0AFF6',
#     'P05825',
#     'P06971',
#     'P06129',
#     'P0A8J8',
#     'P0A6H1',
#     'P02931',
#     'P07001',
#     'P0A6H1',
#     'P05459',
#     'P0AFA2',
#     'P0A9F1',
#     'P0A7Z4',
#     'P0A9Q9',
#     'P08390',
#     'P0ACG1',
#     'P0ACF8',
#     'P07364',
#     'P0A8Q6',
#     'P0AES9',
#     'P08622',
#     'P09372',
#     'P0A6Y8',
#     'P0A6L9',
#     'P0A9Y6',
#     'P31680',
#     'P0A6P5',
#     'P0AAN1',
#     'P08622',
#     'P16926',
#     'P0AFB8',
#     'P07604',
#     'P0AFU4',
#     'P68187',
#     'P0AFX9',
#     'P0AEH1',
#     'P0A6W5',
#     'P0AFJ5',
#     'P0AFB1',
#     'P0A937',
#     'P0A908',
#     'P05852',
#     'P02930',
#     'P02931']),
#   (0.0010681967228459621,
#    'RNA binding',
#    'GO:0003723',
#    ['P0AGK4',
#     'P0A8J8',
#     'P21499',
#     'P21513',
#     'P30850',
#     'P0AGJ5',
#     'P0A832',
#     'P0ABF1',
#     'P0A968',
#     'P05055',
#     'P0A9J0',
#     'P75876',
#     'P0AA39',
#     'P33643',
#     'Q57261',
#     'P46837',
#     'P55135',
#     'P0AG67',
#     'P0AG30',
#     'P63177',
#     'P0A6X3',
#     'P75864',
#     'P0A8M3',
#     'P76273',
#     'P21338',
#     'P0AE70',
#     'P0A894',
#     'P37765',
#     'P36929',
#     'P0A884',
#     'P0AFZ3',
#     'P0AA43',
#     'P0A972',
#     'P30177',
#     'P0AGJ9',
#     'P0A7B5',
#     'P37005',
#     'P0A9Y6',
#     'P0AFF6',
#     'P0A780',
#     'P0AE01',
#     'P06616',
#     'P0A9X9',
#     'P0ACG1',
#     'P0ACF8',
#     'P0A7S3',
#     'P0A7S3',
#     'P02359',
#     'P0A7U3',
#     'P60422',
#     'P0A9W3',
#     'P60438',
#     'P0A7V3',
#     'P0A7M2',
#     'P68679',
#     'P0AD49',
#     'P0A7V8',
#     'P0A7L8',
#     'P0A7S9',
#     'P0ADY7',
#     'P0A7L0',
#     'P0A7W1',
#     'P61175',
#     'P0AG59',
#     'P60624',
#     'P0AG48',
#     'P02413',
#     'P36979',
#     'P39286',
#     'P0ADZ0',
#     'P25519',
#     'P60723',
#     'P0AG63',
#     'P0A7X6',
#     'P06992',
#     'P0ADZ4',
#     'P23003',
#     'P0A7J7',
#     'P42641',
#     'P69222',
#     'P0A7W7',
#     'P0A7Y0',
#     'P0A7M6',
#     'P0A7M9',
#     'P0A7K6',
#     'P0ADY3',
#     'P0AG55',
#     'P0A7L3',
#     'P0AA10',
#     'P0A7J7',
#     'P0A7J3',
#     'P0A7R1',
#     'P0A7R9',
#     'P0A7U7',
#     'P0A7T7',
#     'P0AG63',
#     'P06616',
#     'P02358',
#     'P0C018',
#     'P68919',
#     'P62399',
#     'P0A7S3',
#     'P04805',
#     'P02359',
#     'P60340',
#     'P0A7U3',
#     'P00959',
#     'P00957',
#     'P0A9W3',
#     'P00956',
#     'P0A7Y8',
#     'P0A7L8',
#     'P0A7S9',
#     'P0ADY7',
#     'P07395',
#     'P0A7L0',
#     'P77718',
#     'P76055',
#     'P0A7X3',
#     'P0A8M3',
#     'P14081',
#     'P36979',
#     'P06961',
#     'P33371',
#     'P28634',
#     'P0A7N9',
#     'P08312',
#     'P23003',
#     'P45748',
#     'P32695',
#     'P0A6M4',
#     'P25745',
#     'P0A8E7',
#     'P0A7R5',
#     'P62399',
#     'P45748',
#     'P0AFR4',
#     'P0A9P6',
#     'P21507',
#     'P45577',
#     'P45577',
#     'P33920',
#     'P0A9X9',
#     'P21507',
#     'P0A972',
#     'P02359',
#     'P0A7V3',
#     'P0AG67',
#     'P0A7L3',
#     'P0A9Q5',
#     'P25516',
#     'P36683',
#     'P06992',
#     'P45577',
#     'P0A7V8',
#     'P0A8M3',
#     'P0A7T7',
#     'P69913',
#     'P02358',
#     'P25516',
#     'P36683',
#     'P45577',
#     'P14081',
#     'P21513',
#     'P0AGD7',
#     'P08245',
#     'P0A705',
#     'P69222',
#     'P0A707',
#     'P14081',
#     'P60785',
#     'P0A6N8',
#     'P0CE47',
#     'P0A6M8',
#     'P0A6P1',
#     'P0A6N4',
#     'P07012',
#     'P0A7I0',
#     'P0A7I4',
#     'P0A7I4']),
#   (0.0036742641741427783,
#    'structural constituent of ribosome',
#    'GO:0003735',
#    ['P0A7P5',
#     'P0A7S3',
#     'P02359',
#     'P0A7U3',
#     'P0A7Q6',
#     'P60422',
#     'P0A7K6',
#     'P60438',
#     'P0A7V3',
#     'P0A7M2',
#     'P68679',
#     'P0ADY3',
#     'P0A7V8',
#     'P0A7L8',
#     'P0A7S9',
#     'P0AG67',
#     'P0ADY7',
#     'P0AG55',
#     'P0A7L0',
#     'P0A7L3',
#     'P0A7R9',
#     'P0A7X3',
#     'P0A7W1',
#     'P0AA10',
#     'P61175',
#     'P0AG59',
#     'P60624',
#     'P0AG48',
#     'P0A7U7',
#     'P02413',
#     'P0AG44',
#     'P0A7T7',
#     'P0C018',
#     'P0ADZ0',
#     'P60723',
#     'P0A7N1',
#     'P0A7N9',
#     'P0AG63',
#     'P0ADZ4',
#     'P0A7J7',
#     'P0A7V0',
#     'P0A7W7',
#     'P0A7J3',
#     'P0A7R5',
#     'P0AG51',
#     'P0A7R1',
#     'P0A7N4',
#     'P0A7M6',
#     'P0A7M9',
#     'P0A7T3',
#     'P02358',
#     'P68919',
#     'P0A7K2',
#     'P62399']),
#   (0.005092043899540847,
#    'rRNA binding',
#    'GO:0019843',
#    ['P0A7S3',
#     'P02359',
#     'P0A7U3',
#     'P60422',
#     'P0A9W3',
#     'P60438',
#     'P0A7V3',
#     'P0A7M2',
#     'P68679',
#     'P0AD49',
#     'P0A7V8',
#     'P0A7L8',
#     'P0A7S9',
#     'P0ADY7',
#     'P0A7L0',
#     'P0A7W1',
#     'P61175',
#     'P0AG59',
#     'P60624',
#     'P0AG48',
#     'P02413',
#     'P36979',
#     'P39286',
#     'P0ADZ0',
#     'P25519',
#     'P60723',
#     'P0AG63',
#     'P0A7X6',
#     'P06992',
#     'P0ADZ4',
#     'P23003',
#     'P0A7J7',
#     'P42641',
#     'P69222',
#     'P0A7W7',
#     'P0A7Y0',
#     'P0A7M6',
#     'P0A7M9',
#     'P0A7K6',
#     'P0ADY3',
#     'P0AG55',
#     'P0A7L3',
#     'P0AA10',
#     'P0A7J7',
#     'P0A7J3',
#     'P0A7R1',
#     'P0A7R9',
#     'P0A7U7',
#     'P0A7T7',
#     'P0AG63',
#     'P06616',
#     'P02358',
#     'P0C018',
#     'P68919',
#     'P62399']),
#   (0.007216465321729826,
#    'structural molecule activity',
#    'GO:0005198',
#    ['P29744',
#     'P33235',
#     'P0A6S3',
#     'P04949',
#     'P0AAC8',
#     'P0ACC3',
#     'P76541',
#     'P0A910',
#     'P0A7P5',
#     'P0A7S3',
#     'P02359',
#     'P0A7U3',
#     'P0A7Q6',
#     'P60422',
#     'P0A7K6',
#     'P60438',
#     'P0A7V3',
#     'P0A7M2',
#     'P68679',
#     'P0ADY3',
#     'P0A7V8',
#     'P0A7L8',
#     'P0A7S9',
#     'P0AG67',
#     'P0ADY7',
#     'P0AG55',
#     'P0A7L0',
#     'P0A7L3',
#     'P0A7R9',
#     'P0A7X3',
#     'P0A7W1',
#     'P0AA10',
#     'P61175',
#     'P0AG59',
#     'P60624',
#     'P0AG48',
#     'P0A7U7',
#     'P02413',
#     'P0AG44',
#     'P0A7T7',
#     'P0C018',
#     'P0ADZ0',
#     'P60723',
#     'P0A7N1',
#     'P0A7N9',
#     'P0AG63',
#     'P0ADZ4',
#     'P0A7J7',
#     'P0A7V0',
#     'P0A7W7',
#     'P0A7J3',
#     'P0A7R5',
#     'P0AG51',
#     'P0A7R1',
#     'P0A7N4',
#     'P0A7M6',
#     'P0A7M9',
#     'P0A7T3',
#     'P02358',
#     'P68919',
#     'P0A7K2',
#     'P62399']),
#   (0.014170159359436718,
#    'ligase activity',
#    'GO:0016874',
#    ['P0A8N5',
#     'P0A8N3',
#     'P0AB77',
#     'P0ADT5',
#     'P21888',
#     'P0A8M3',
#     'P27305',
#     'P21888',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P43672',
#     'P00962',
#     'P04805',
#     'P00959',
#     'P00957',
#     'P00956',
#     'P0A8M0',
#     'P07395',
#     'P08312',
#     'P0A8N5',
#     'P0A8N3',
#     'P0A8N7',
#     'P0A8M3',
#     'P60906',
#     'P0AGJ9',
#     'P00954',
#     'P00961',
#     'P11875',
#     'P00961',
#     'P00960',
#     'P16659',
#     'P21888',
#     'P18133',
#     'P77756',
#     'P0A8N7',
#     'P0A9C5',
#     'P22106',
#     'P00963',
#     'P0AES0',
#     'P18843',
#     'P18133',
#     'P0A6F1',
#     'P00968',
#     'P15254',
#     'P22106',
#     'P04079',
#     'P04079',
#     'P18843',
#     'P00968',
#     'P37773',
#     'P04425',
#     'P0ABQ0',
#     'P11454',
#     'P0ADI4',
#     'P10378',
#     'P31663',
#     'P0A6J8',
#     'P07862',
#     'P17952',
#     'P14900',
#     'P22188',
#     'P0A7D7',
#     'P11880',
#     'P11880',
#     'P08192',
#     'P08192',
#     'P0A6W9',
#     'P0A6E4',
#     'P0A6E9',
#     'P13000',
#     'P08178',
#     'P52097',
#     'P06709',
#     'P09029',
#     'P0A7E5',
#     'P0A7D4',
#     'P15640',
#     'P32099',
#     'P24182',
#     'P0A836',
#     'P0AGE9',
#     'P76085',
#     'P69451',
#     'P69451',
#     'P69451',
#     'P37353',
#     'P27550',
#     'P27550',
#     'P76085',
#     'Q46927',
#     'P12282',
#     'P0ABD5',
#     'P0A9Q5',
#     'P0ABD8',
#     'P24182',
#     'P15042']),
#   (0.016708954119011427,
#    'magnesium ion binding',
#    'GO:0000287',
#    ['P0AFG3',
#     'P0A8L1',
#     'P14294',
#     'P0AES2',
#     'P07118',
#     'P0A7J0',
#     'P0A836',
#     'P0A6F5',
#     'P07003',
#     'P31057',
#     'P0A6A3',
#     'P21513',
#     'P0ACB2',
#     'P0A7A9',
#     'P0ACC7',
#     'P15877',
#     'P05055',
#     'P0A796',
#     'P05793',
#     'P04425',
#     'P0AG16',
#     'P77488',
#     'P0AFG8',
#     'P07395',
#     'P08142',
#     'P0A8N5',
#     'P0AEJ2',
#     'P76055',
#     'P75838',
#     'P64636',
#     'P37128',
#     'P0A7B8',
#     'P52006',
#     'P23522',
#     'P0A817',
#     'P39304',
#     'P0A6V1',
#     'P38051',
#     'P0AD61',
#     'P04995',
#     'P06961',
#     'Q46893',
#     'P21599',
#     'P0AFC0',
#     'P30125',
#     'P0A6E9',
#     'P0A951',
#     'P76423',
#     'P30870',
#     'P05041',
#     'P0A8N3',
#     'P00864',
#     'P0A9K7',
#     'P21829',
#     'P27859',
#     'P0A884',
#     'P0ADG4',
#     'P38506',
#     'P19624',
#     'P08337',
#     'P0ADI4',
#     'P77625',
#     'P13000',
#     'P17952',
#     'P64554',
#     'P29208',
#     'P69503',
#     'P08312',
#     'P0AE67',
#     'P27278',
#     'P77150',
#     'P77475',
#     'P16456',
#     'P0AGG0',
#     'P0AEP3',
#     'P75809',
#     'P60472',
#     'Q93K97',
#     'P0A717',
#     'P0A9M2',
#     'P27848',
#     'P0A873',
#     'P22188',
#     'P31120',
#     'P0A993',
#     'P33221',
#     'P23538',
#     'P06999',
#     'P0A6H5',
#     'P60757',
#     'P0ADM8',
#     'P42641',
#     'P04951',
#     'P0A6T3',
#     'P0A7B5',
#     'P06968',
#     'P36938',
#     'P0A7D4',
#     'P52061',
#     'P0AGB0',
#     'P30014',
#     'P0A6P9',
#     'P0A6D7',
#     'P40191',
#     'P22259',
#     'P0A8Y5',
#     'P76014',
#     'P77247',
#     'P0A6K6',
#     'P0C0K3',
#     'P08839',
#     'P32166',
#     'P0AF24',
#     'P05852',
#     'P08200',
#     'P32662',
#     'P69441',
#     'P0A7Y0',
#     'P75792',
#     'P0A9M5',
#     'P10908',
#     'P0ADP0',
#     'P0A8F0',
#     'P22255',
#     'P0A8Y3',
#     'P45799']),
#   (0.0198163054027285,
#    'ligase activity, forming carbon-nitrogen bonds',
#    'GO:0016879',
#    ['P18133',
#     'P77756',
#     'P0A8N7',
#     'P0A9C5',
#     'P22106',
#     'P00963',
#     'P0AES0',
#     'P18843',
#     'P18133',
#     'P0A6F1',
#     'P00968',
#     'P15254',
#     'P22106',
#     'P04079',
#     'P04079',
#     'P18843',
#     'P00968',
#     'P37773',
#     'P04425',
#     'P0ABQ0',
#     'P11454',
#     'P0ADI4',
#     'P10378',
#     'P31663',
#     'P0A6J8',
#     'P07862',
#     'P17952',
#     'P14900',
#     'P22188',
#     'P0A7D7',
#     'P11880',
#     'P11880',
#     'P08192',
#     'P08192',
#     'P0A6W9',
#     'P0A6E4',
#     'P0A6E9',
#     'P13000',
#     'P08178',
#     'P52097',
#     'P06709',
#     'P09029',
#     'P0A7E5',
#     'P0A7D4',
#     'P15640',
#     'P32099',
#     'P24182']),
#   (0.02027625815747051,
#    'aminoacyl-tRNA ligase activity',
#    'GO:0004812',
#    ['P0A8M3',
#     'P27305',
#     'P21888',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P43672',
#     'P00962',
#     'P04805',
#     'P00959',
#     'P00957',
#     'P00956',
#     'P0A8M0',
#     'P07395',
#     'P08312',
#     'P0A8N5',
#     'P0A8N3',
#     'P0A8N7',
#     'P0A8M3',
#     'P60906',
#     'P0AGJ9',
#     'P00954',
#     'P00961',
#     'P11875',
#     'P00961',
#     'P00960',
#     'P16659',
#     'P21888']),
#   (0.026020259113962805,
#    'catalytic activity, acting on a tRNA',
#    'GO:0140101',
#    ['P0A8M3',
#     'P27305',
#     'P21888',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P43672',
#     'P00962',
#     'P04805',
#     'P00959',
#     'P00957',
#     'P00956',
#     'P0A8M0',
#     'P07395',
#     'P08312',
#     'P0A8N5',
#     'P0A8N3',
#     'P0A8N7',
#     'P0A8M3',
#     'P60906',
#     'P0AGJ9',
#     'P00954',
#     'P00961',
#     'P11875',
#     'P00961',
#     'P00960',
#     'P16659',
#     'P21888',
#     'P07813',
#     'P07118',
#     'P00957',
#     'P00956',
#     'P0A8M3',
#     'P0AAR3',
#     'P0A6M4',
#     'P64483',
#     'P00957',
#     'P64483',
#     'P0AAR3',
#     'P0A6M4',
#     'P0A6M4',
#     'P0A6M4',
#     'P16659',
#     'P60340',
#     'Q57261',
#     'P0A7Y8',
#     'P0A6X1',
#     'P0A847',
#     'P16384',
#     'P36979',
#     'P28634',
#     'P31825',
#     'P23003',
#     'P0AE01',
#     'P0A8I5',
#     'P0A873',
#     'P0A873',
#     'P0AE01',
#     'P06961',
#     'P06961',
#     'P06961',
#     'P33371',
#     'P32695',
#     'P32695',
#     'P33667',
#     'P52097',
#     'Q46927',
#     'P0A7D1',
#     'P0A7F9',
#     'P23882',
#     'P0A6M4']),
#   (0.02845134212783707,
#    'small molecule binding',
#    'GO:0036094',
#    ['P0A9Z1',
#     'P37646',
#     'P0AFG3',
#     'P28248',
#     'P07024',
#     'P0AGE9',
#     'P00968',
#     'P0ADG7',
#     'P09155',
#     'P08331',
#     'P30748',
#     'P68688',
#     'P76491',
#     'P15770',
#     'P0A9M2',
#     'P0A993',
#     'P0A840',
#     'P52061',
#     'P69874',
#     'P39830',
#     'P0AFF6',
#     'P0ACE7',
#     'P0ABH9',
#     'P15038',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P06993',
#     'P0A9C5',
#     'P0A836',
#     'P76085',
#     'P0AF03',
#     'P0A8J8',
#     'P0A6F1',
#     'P0AES0',
#     'P0A6F5',
#     'P00962',
#     'P04805',
#     'P0A9P6',
#     'P0A6A3',
#     'P07363',
#     'P38134',
#     'P0AG20',
#     'P28903',
#     'P21156',
#     'P00968',
#     'P46889',
#     'P69451',
#     'P09980',
#     'P27240',
#     'P15254',
#     'P00959',
#     'P00957',
#     'P10408',
#     'P0ABF1',
#     'P0A9W3',
#     'P0AAG5',
#     'P23845',
#     'P00956',
#     'P0A9M0',
#     'P20083',
#     'P0A8M0',
#     'P0ABB0',
#     'P22523',
#     'P21507',
#     'P0A796',
#     'P37617',
#     'P0A8F8',
#     'P0A698',
#     'P0ABB8',
#     'P04425',
#     'P33941',
#     'P0ABD5',
#     'P0AEW6',
#     'P43672',
#     'P0A6H1',
#     'P24230',
#     'P16676',
#     'P0AES6',
#     'P37773',
#     'P07395',
#     'P03004',
#     'P43329',
#     'P0A812',
#     'P0A8N5',
#     'P0ABA6',
#     'P08622',
#     'P0ABB4',
#     'P0AFI2',
#     'P77718',
#     'P0A9Q5',
#     'P0AG30',
#     'P52612',
#     'P76055',
#     'P03018',
#     'P0AES4',
#     'P0A8M3',
#     'P0A6I6',
#     'P0A7B8',
#     'P29018',
#     'P30958',
#     'P63389',
#     'P0A6E4',
#     'P06710',
#     'P0A817',
#     'P39838',
#     'P00452',
#     'P0A6Y8',
#     'P37624',
#     'P24554',
#     'P0AFA2',
#     'P16384',
#     'P0AEJ4',
#     'P0A6V1',
#     'P11454',
#     'P0A7E9',
#     'P0AE82',
#     'P23331',
#     'P14175',
#     'P60906',
#     'P31663',
#     'P0A9U1',
#     'P45425',
#     'P23909',
#     'P0AD61',
#     'P06961',
#     'P0A894',
#     'P27305',
#     'P21599',
#     'P77499',
#     'P00561',
#     'P13458',
#     'P23886',
#     'P0A6E9',
#     'P31473',
#     'P0AEY3',
#     'P37353',
#     'Q59385',
#     'P76423',
#     'P08956',
#     'P30870',
#     'P0ABH0',
#     'P23837',
#     'P23878',
#     'P0AFB8',
#     'P25519',
#     'P0A8N3',
#     'P0AF08',
#     'P06989',
#     'P07648',
#     'P07604',
#     'P60546',
#     'P0AEC3',
#     'P52097',
#     'P27550',
#     'P0AAI3',
#     'P08660',
#     'P23524',
#     'P31548',
#     'P0A6E6',
#     'P60752',
#     'Q46927',
#     'P0AEC5',
#     'P22106',
#     'P60240',
#     'P0A6J8',
#     'P12282',
#     'P06709',
#     'P0ACB0',
#     'P09029',
#     'P36879',
#     'P13000',
#     'P77756',
#     'P15031',
#     'P77265',
#     'P63284',
#     'P0AD12',
#     'P10378',
#     'P17952',
#     'P08178',
#     'P00562',
#     'P64612',
#     'P04983',
#     'P0A8N7',
#     'P0AAG8',
#     'P37774',
#     'P00963',
#     'P08312',
#     'P77737',
#     'P27278',
#     'P0A7B3',
#     'P77150',
#     'P16456',
#     'P31060',
#     'P0AGG0',
#     'P75957',
#     'P0A8F4',
#     'P04079',
#     'P17115',
#     'P0AG40',
#     'P0A7H0',
#     'P14900',
#     'P0A9T8',
#     'P31802',
#     'P0A717',
#     'P0A8D0',
#     'P77279',
#     'P75831',
#     'P0A6Z3',
#     'P76027',
#     'P22188',
#     'P63284-2',
#     'P75867',
#     'P0A9V1',
#     'P33221',
#     'P23538',
#     'P0A6Z1',
#     'P0AEZ3',
#     'P06999',
#     'P0A6H5',
#     'P0AFU4',
#     'P60757',
#     'P27300',
#     'P0A7D7',
#     'P0AGJ9',
#     'P0A7E5',
#     'P45748',
#     'P62615',
#     'P36928',
#     'P0A9K3',
#     'P0A9U3',
#     'P00954',
#     'P0A6T3',
#     'P0A7B5',
#     'P11880',
#     'P00961',
#     'P0AF28',
#     'P0ADT5',
#     'P15640',
#     'P0ABU2',
#     'P08192',
#     'P69874',
#     'P16659',
#     'P00547',
#     'P77570',
#     'P0A6D7',
#     'P76658',
#     'P0AAH0',
#     'P40191',
#     'P0AAG3',
#     'P46859',
#     'P22259',
#     'P0A9R7',
#     'P18843',
#     'P32099',
#     'P0AAF6',
#     'P37647',
#     'P76014',
#     'P0A6F9',
#     'P0A6I3',
#     'P0A799',
#     'P68187',
#     'P07862',
#     'P24182',
#     'P0C0K3',
#     'P0A7G6',
#     'P0A6V8',
#     'P21888',
#     'P0A6W9',
#     'P0A6F3',
#     'P37903',
#     'P0A9J6',
#     'P0A9H5',
#     'P0AEW9',
#     'P23917',
#     'P75959',
#     'P0A6I0',
#     'P25745',
#     'P00960',
#     'P75745',
#     'P69441',
#     'P0A7Y0',
#     'P30750',
#     'P0A8E7',
#     'P63386',
#     'P0A9X4',
#     'P0AF67',
#     'P07109',
#     'P0A720',
#     'P0A9Z1',
#     'P11875',
#     'P0AAH8',
#     'P0A763',
#     'P0AAV4',
#     'P09833',
#     'P0A6Y8',
#     'P23909',
#     'P69931',
#     'P0A6Z1',
#     'P76014',
#     'P0AF67',
#     'P0A6V1',
#     'P27550',
#     'P69441',
#     'P0ACJ8',
#     'P0A8V6',
#     'P28903',
#     'P09372',
#     'P42641',
#     'P0AEZ9',
#     'P0AG20',
#     'P23845',
#     'P22523',
#     'P0A6P5',
#     'P0AGD7',
#     'P0A705',
#     'P0A6T5',
#     'P14081',
#     'P0A9A6',
#     'P0AAN3',
#     'P33650',
#     'P60785',
#     'P76245',
#     'P0A894',
#     'P39286',
#     'P25519',
#     'P24203',
#     'P32132',
#     'P25522',
#     'P42641',
#     'P0A7I7',
#     'P0A7D4',
#     'P0ABU2',
#     'P0CE47',
#     'P0A6P7',
#     'P0A7I4',
#     'P0A6M8',
#     'P06616',
#     'P0A8E7',
#     'P10121',
#     'P0A8F0',
#     'P33030',
#     'P05055',
#     'P76010',
#     'P0A796',
#     'P14081',
#     'P39286',
#     'P25522',
#     'P42641',
#     'P0A7I4',
#     'P0A6P5',
#     'P0A705',
#     'P28903',
#     'P0A796',
#     'P31979',
#     'P77258',
#     'P38038',
#     'P12008',
#     'P0ABQ0',
#     'P0A7E1',
#     'P33371',
#     'P0ACY1',
#     'P42593',
#     'P77285',
#     'P33232',
#     'P17117',
#     'P13033',
#     'P0AGE6',
#     'P0A9C0',
#     'P0ABY4',
#     'P41407',
#     'P0A8G6',
#     'P65367',
#     'P03817',
#     'P32695',
#     'P61949',
#     'P38489',
#     'P0ACB4',
#     'P0AFI7',
#     'P31979',
#     'P0AET8',
#     'P0A9B2',
#     'P07001',
#     'P76558',
#     'P0ABQ2',
#     'P04036',
#     'P75913',
#     'P26616',
#     'P33599',
#     'P05459',
#     'P0AEA8',
#     'P37666',
#     'P35340',
#     'P0A9B6',
#     'P30125',
#     'P0A6S7',
#     'P06988',
#     'P19624',
#     'P0A9Q9',
#     'P0A6L7',
#     'P0A7B3',
#     'P0A8G6',
#     'P08390',
#     'P27829',
#     'P0A9T0',
#     'P08200',
#     'P37769',
#     'P0AEK2',
#     'P52643',
#     'P75960',
#     'P15042',
#     'P07639',
#     'P09147',
#     'P07004',
#     'P0A9B2',
#     'P0AB67',
#     'P25526',
#     'P0ABQ2',
#     'P17846',
#     'P04036',
#     'P05793',
#     'P00350',
#     'P0A6X1',
#     'P0AC53',
#     'P00561',
#     'P06715',
#     'P25539',
#     'P0A9Q9',
#     'P00562',
#     'P15770',
#     'P0A9J4',
#     'P0A8G6',
#     'P0AEK2',
#     'P38038',
#     'P67910',
#     'P0ABQ4',
#     'P45568',
#     'P0ABQ4',
#     'P38038',
#     'P07003',
#     'P0A9P0',
#     'P77748',
#     'P00393',
#     'P0A6U3',
#     'P08142',
#     'P0AC41',
#     'P0A9P4',
#     'P33940',
#     'P33371',
#     'P09546',
#     'P06149',
#     'P0AE45',
#     'P0A9C0',
#     'P76389',
#     'Q46871',
#     'P0A8G6',
#     'P37747',
#     'P76007',
#     'P0AEY5',
#     'P08373',
#     'P32695',
#     'P40874',
#     'P27306',
#     'P0AE78',
#     'P0AEC0',
#     'P13035',
#     'P77748',
#     'P35340',
#     'P25535',
#     'P00363',
#     'P06715',
#     'P06149',
#     'P42593',
#     'P25534',
#     'P75728',
#     'P24232',
#     'Q46871',
#     'P08373',
#     'P28861',
#     'P28903',
#     'P69451',
#     'P24232',
#     'P06959',
#     'P0AFG6',
#     'P69451',
#     'P0AD65',
#     'P02918',
#     'P0AEB2',
#     'P08506',
#     'P06709',
#     'P00968',
#     'P04968',
#     'P30860',
#     'P0AEM9',
#     'P0AEU0',
#     'P04391',
#     'P22106',
#     'P0ACI6',
#     'P30860',
#     'P0A6D0',
#     'P37902',
#     'P37902',
#     'P0A7B5',
#     'P0A9T0',
#     'P15877',
#     'P0A9W0',
#     'P0ADE8',
#     'P0ABQ4',
#     'P0ABQ4',
#     'P0ABQ4',
#     'P04982',
#     'P39265',
#     'P02924',
#     'P02925',
#     'P0AEN8',
#     'P39325',
#     'P0A6T3',
#     'P0A6V8',
#     'P06721',
#     'P0A853',
#     'P00490',
#     'P22256',
#     'P0AC86',
#     'P69908',
#     'P0A6B7',
#     'P75823',
#     'P21169',
#     'P04968',
#     'P12998',
#     'P12995',
#     'P75863',
#     'P04693',
#     'P76316',
#     'P00861',
#     'P0A959',
#     'P67080',
#     'Q46925',
#     'P0A879',
#     'P0AB77',
#     'P29012',
#     'P32157',
#     'P00509',
#     'P23256',
#     'P06986',
#     'P0A825',
#     'P0A6B4',
#     'P77434',
#     'P28305',
#     'P09053',
#     'P00934',
#     'P23721',
#     'P00926',
#     'P40191',
#     'P27833',
#     'P23893',
#     'P77581',
#     'P0ABK5',
#     'P0AFG3',
#     'P27302',
#     'P07003',
#     'P77488',
#     'P0AFG8',
#     'P52647',
#     'P08142',
#     'P31550',
#     'P11454',
#     'P0A6A8',
#     'P0ADI4',
#     'P31550',
#     'P13009',
#     'P0AFI7',
#     'P0A8V2',
#     'P0ABF6',
#     'P0ACP7',
#     'P24232']),
#   (0.03221843391232357,
#    'pyrophosphatase activity',
#    'GO:0016462',
#    ['P04079',
#     'P06710',
#     'P0AEI6',
#     'P52061',
#     'P0ABH9',
#     'P0A6F5',
#     'P46889',
#     'P0A9W3',
#     'P0AAG5',
#     'P0A9M0',
#     'P21507',
#     'P37617',
#     'P0A8F8',
#     'P0A698',
#     'P33941',
#     'P43672',
#     'P0A6H1',
#     'P16676',
#     'P52612',
#     'P29018',
#     'P63389',
#     'P06710',
#     'P0A6Y8',
#     'P37624',
#     'P14175',
#     'P0A9U1',
#     'P23909',
#     'P77499',
#     'P23886',
#     'P31473',
#     'Q59385',
#     'P23878',
#     'P25519',
#     'P0AF08',
#     'P0AAI3',
#     'P31548',
#     'P60752',
#     'P60240',
#     'P36879',
#     'P15031',
#     'P77265',
#     'P64612',
#     'P04983',
#     'P0AAG8',
#     'P37774',
#     'P77737',
#     'P31060',
#     'P75957',
#     'P0A9T8',
#     'P64602',
#     'P77279',
#     'P75831',
#     'P0A6Z3',
#     'P76027',
#     'P0A9V1',
#     'P0A6Z1',
#     'P0AEZ3',
#     'P0A6H5',
#     'P0A9U3',
#     'P0ABU2',
#     'P69874',
#     'P0AAH0',
#     'P0AAG3',
#     'P0A9R7',
#     'P0AAF6',
#     'P68187',
#     'P30750',
#     'P63386',
#     'P0AF67',
#     'P07109',
#     'P0AAH8',
#     'P09833',
#     'P15254',
#     'P37624',
#     'P63284',
#     'P0A6Z3',
#     'P63284-2',
#     'P15640',
#     'P0ABH9',
#     'P0A9M0',
#     'P0A6H1',
#     'P0A6G7',
#     'P0AAI3',
#     'P75867',
#     'P43329',
#     'P0AG30',
#     'P08956',
#     'P60240',
#     'P0ACB0',
#     'P09980',
#     'P24230',
#     'P0A812',
#     'P03018',
#     'P07648',
#     'P0ACB0',
#     'P15038',
#     'P46889',
#     'P0A812',
#     'P03018',
#     'P0A8J8',
#     'P0A9P6',
#     'P0A9P6',
#     'P21507',
#     'P43329',
#     'P21499',
#     'P0AES6',
#     'P0AES4',
#     'P24554',
#     'P0A7G6',
#     'P46889',
#     'P03018',
#     'P30958',
#     'P20083',
#     'P0AES6',
#     'P0AFI2',
#     'P0AES4',
#     'P0AES6',
#     'P0AES4',
#     'P0A8H8',
#     'P21507',
#     'P0AG30',
#     'P09372',
#     'P0A6L9',
#     'P52613',
#     'P06974',
#     'P31068',
#     'P0ABZ1',
#     'P15070',
#     'P0A6S0',
#     'P25798',
#     'P23845',
#     'P0A6P5',
#     'P0AGD7',
#     'P0A705',
#     'P14081',
#     'P0A9A6',
#     'P0AAN3',
#     'P60785',
#     'P39286',
#     'P25519',
#     'P24203',
#     'P32132',
#     'P25522',
#     'P42641',
#     'P0CE47',
#     'P0A7I4',
#     'P0A6M8',
#     'P06616',
#     'P10121',
#     'P33030',
#     'P0A8H6',
#     'P0AAI3',
#     'P07024',
#     'P0A7A9',
#     'P0A7A9',
#     'P30871',
#     'P0AFL6',
#     'P0A840',
#     'P0AEY3',
#     'P52061',
#     'P25536',
#     'P0A729',
#     'P75838',
#     'P0AEY3',
#     'P52006',
#     'P52006',
#     'P06968',
#     'P0AFC0',
#     'P08337',
#     'P08337',
#     'P52061',
#     'P52061',
#     'P52061',
#     'P25536',
#     'P25536',
#     'P37128',
#     'P52006',
#     'P25536',
#     'P05637',
#     'P05637',
#     'P43341',
#     'P0AFC0',
#     'P0AEI6',
#     'P0AEI6',
#     'P08337',
#     'P08337',
#     'P06989',
#     'P06282',
#     'Q93K97',
#     'Q93K97',
#     'P45799',
#     'P0A924',
#     'P0A924',
#     'P76445']),
#   (0.03283803789191233,
#    'anion binding',
#    'GO:0043168',
#    ['P0ABH9',
#     'P15038',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P06993',
#     'P0A9C5',
#     'P0A836',
#     'P76085',
#     'P0AF03',
#     'P0A8J8',
#     'P0A6F1',
#     'P0AES0',
#     'P0A6F5',
#     'P00962',
#     'P04805',
#     'P0A9P6',
#     'P0A6A3',
#     'P07363',
#     'P38134',
#     'P0AG20',
#     'P28903',
#     'P21156',
#     'P00968',
#     'P46889',
#     'P69451',
#     'P09980',
#     'P27240',
#     'P15254',
#     'P00959',
#     'P00957',
#     'P10408',
#     'P0ABF1',
#     'P0A9W3',
#     'P0AAG5',
#     'P23845',
#     'P00956',
#     'P0A9M0',
#     'P20083',
#     'P0A8M0',
#     'P0ABB0',
#     'P22523',
#     'P21507',
#     'P0A796',
#     'P37617',
#     'P0A8F8',
#     'P0A698',
#     'P0ABB8',
#     'P04425',
#     'P33941',
#     'P0ABD5',
#     'P0AEW6',
#     'P43672',
#     'P0A6H1',
#     'P24230',
#     'P16676',
#     'P0AES6',
#     'P37773',
#     'P07395',
#     'P03004',
#     'P43329',
#     'P0A812',
#     'P0A8N5',
#     'P0ABA6',
#     'P08622',
#     'P0ABB4',
#     'P0AFI2',
#     'P77718',
#     'P0A9Q5',
#     'P0AG30',
#     'P52612',
#     'P76055',
#     'P03018',
#     'P0AES4',
#     'P0A8M3',
#     'P0A6I6',
#     'P0A7B8',
#     'P29018',
#     'P30958',
#     'P63389',
#     'P0A6E4',
#     'P06710',
#     'P0A817',
#     'P39838',
#     'P00452',
#     'P0A6Y8',
#     'P37624',
#     'P24554',
#     'P0AFA2',
#     'P16384',
#     'P0AEJ4',
#     'P0A6V1',
#     'P11454',
#     'P0A7E9',
#     'P0AE82',
#     'P23331',
#     'P14175',
#     'P60906',
#     'P31663',
#     'P0A9U1',
#     'P45425',
#     'P23909',
#     'P0AD61',
#     'P06961',
#     'P0A894',
#     'P27305',
#     'P21599',
#     'P77499',
#     'P00561',
#     'P13458',
#     'P23886',
#     'P0A6E9',
#     'P31473',
#     'P0AEY3',
#     'P37353',
#     'Q59385',
#     'P76423',
#     'P08956',
#     'P30870',
#     'P0ABH0',
#     'P23837',
#     'P23878',
#     'P0AFB8',
#     'P25519',
#     'P0A8N3',
#     'P0AF08',
#     'P06989',
#     'P07648',
#     'P07604',
#     'P60546',
#     'P0AEC3',
#     'P52097',
#     'P27550',
#     'P0AAI3',
#     'P08660',
#     'P23524',
#     'P31548',
#     'P0A6E6',
#     'P60752',
#     'Q46927',
#     'P0AEC5',
#     'P22106',
#     'P60240',
#     'P0A6J8',
#     'P12282',
#     'P06709',
#     'P0ACB0',
#     'P09029',
#     'P36879',
#     'P13000',
#     'P77756',
#     'P15031',
#     'P77265',
#     'P63284',
#     'P0AD12',
#     'P10378',
#     'P17952',
#     'P08178',
#     'P00562',
#     'P64612',
#     'P04983',
#     'P0A8N7',
#     'P0AAG8',
#     'P37774',
#     'P00963',
#     'P08312',
#     'P77737',
#     'P27278',
#     'P0A7B3',
#     'P77150',
#     'P16456',
#     'P31060',
#     'P0AGG0',
#     'P75957',
#     'P0A8F4',
#     'P04079',
#     'P17115',
#     'P0AG40',
#     'P0A7H0',
#     'P14900',
#     'P0A9T8',
#     'P31802',
#     'P0A717',
#     'P0A8D0',
#     'P77279',
#     'P75831',
#     'P0A6Z3',
#     'P76027',
#     'P22188',
#     'P63284-2',
#     'P75867',
#     'P0A9V1',
#     'P33221',
#     'P23538',
#     'P0A6Z1',
#     'P0AEZ3',
#     'P06999',
#     'P0A6H5',
#     'P0AFU4',
#     'P60757',
#     'P27300',
#     'P0A7D7',
#     'P0AGJ9',
#     'P0A7E5',
#     'P45748',
#     'P62615',
#     'P36928',
#     'P0A9K3',
#     'P0A9U3',
#     'P00954',
#     'P0A6T3',
#     'P0A7B5',
#     'P11880',
#     'P00961',
#     'P0AF28',
#     'P0ADT5',
#     'P15640',
#     'P0ABU2',
#     'P08192',
#     'P69874',
#     'P16659',
#     'P00547',
#     'P77570',
#     'P0A6D7',
#     'P76658',
#     'P0AAH0',
#     'P40191',
#     'P0AAG3',
#     'P46859',
#     'P22259',
#     'P0A9R7',
#     'P18843',
#     'P32099',
#     'P0AAF6',
#     'P37647',
#     'P76014',
#     'P0A6F9',
#     'P0A6I3',
#     'P0A799',
#     'P68187',
#     'P07862',
#     'P24182',
#     'P0C0K3',
#     'P0A7G6',
#     'P0A6V8',
#     'P21888',
#     'P0A6W9',
#     'P0A6F3',
#     'P37903',
#     'P0A9J6',
#     'P0A9H5',
#     'P0AEW9',
#     'P23917',
#     'P75959',
#     'P0A6I0',
#     'P25745',
#     'P00960',
#     'P75745',
#     'P69441',
#     'P0A7Y0',
#     'P30750',
#     'P0A8E7',
#     'P63386',
#     'P0A9X4',
#     'P0AF67',
#     'P07109',
#     'P0A720',
#     'P0A9Z1',
#     'P11875',
#     'P0AAH8',
#     'P0A763',
#     'P0AAV4',
#     'P09833',
#     'P0AEZ9',
#     'P0AG20',
#     'P23845',
#     'P22523',
#     'P0A6P5',
#     'P0AGD7',
#     'P0A705',
#     'P0A6T5',
#     'P14081',
#     'P0A9A6',
#     'P0AAN3',
#     'P33650',
#     'P60785',
#     'P76245',
#     'P0A894',
#     'P39286',
#     'P25519',
#     'P24203',
#     'P32132',
#     'P25522',
#     'P42641',
#     'P0A7I7',
#     'P0A7D4',
#     'P0ABU2',
#     'P0CE47',
#     'P0A6P7',
#     'P0A7I4',
#     'P0A6M8',
#     'P06616',
#     'P0A8E7',
#     'P10121',
#     'P0A8F0',
#     'P33030',
#     'P69451',
#     'P24232',
#     'P06959',
#     'P0AFG6',
#     'P69451',
#     'P0AD65',
#     'P02918',
#     'P0AEB2',
#     'P08506',
#     'P06709',
#     'P00968',
#     'P04968',
#     'P30860',
#     'P0AEM9',
#     'P0AEU0',
#     'P04391',
#     'P22106',
#     'P0ACI6',
#     'P30860',
#     'P0A6D0',
#     'P37902',
#     'P37902',
#     'P0A7B5',
#     'P0A9T0',
#     'P15877',
#     'P0A9W0',
#     'P0ADE8',
#     'P0ABQ4',
#     'P0ABQ4',
#     'P0ABQ4',
#     'P52643',
#     'P06721',
#     'P0A853',
#     'P00490',
#     'P22256',
#     'P0AC86',
#     'P69908',
#     'P0A6B7',
#     'P75823',
#     'P21169',
#     'P04968',
#     'P12998',
#     'P12995',
#     'P75863',
#     'P04693',
#     'P76316',
#     'P00861',
#     'P0A959',
#     'P67080',
#     'Q46925',
#     'P0A879',
#     'P0AB77',
#     'P29012',
#     'P32157',
#     'P00509',
#     'P23256',
#     'P06986',
#     'P0A825',
#     'P0A6B4',
#     'P77434',
#     'P28305',
#     'P09053',
#     'P00934',
#     'P23721',
#     'P00926',
#     'P40191',
#     'P27833',
#     'P23893',
#     'P77581',
#     'P0ABK5',
#     'P31979',
#     'P77258',
#     'P38038',
#     'P12008',
#     'P0ABQ0',
#     'P0A7E1',
#     'P33371',
#     'P0ACY1',
#     'P42593',
#     'P77285',
#     'P33232',
#     'P17117',
#     'P13033',
#     'P0AGE6',
#     'P0A9C0',
#     'P0ABY4',
#     'P41407',
#     'P0A8G6',
#     'P65367',
#     'P03817',
#     'P32695',
#     'P61949',
#     'P38489',
#     'P0ACB4',
#     'P0AFI7',
#     'P0AFG3',
#     'P27302',
#     'P07003',
#     'P77488',
#     'P0AFG8',
#     'P52647',
#     'P08142',
#     'P31550',
#     'P0ABU0',
#     'P38038',
#     'P07003',
#     'P0A9P0',
#     'P77748',
#     'P00393',
#     'P0A6U3',
#     'P08142',
#     'P0AC41',
#     'P0A9P4',
#     'P33940',
#     'P33371',
#     'P09546',
#     'P06149',
#     'P0AE45',
#     'P0A9C0',
#     'P76389',
#     'Q46871',
#     'P0A8G6',
#     'P37747',
#     'P76007',
#     'P0AEY5',
#     'P08373',
#     'P32695',
#     'P40874',
#     'P27306',
#     'P0AE78',
#     'P0AEC0',
#     'P13035',
#     'P77748',
#     'P35340',
#     'P25535',
#     'P00363',
#     'P06715',
#     'P06149',
#     'P42593',
#     'P25534',
#     'P75728',
#     'P24232',
#     'Q46871',
#     'P08373',
#     'P28861',
#     'P38038',
#     'P67910',
#     'P0ABQ4',
#     'P28903',
#     'P28903',
#     'P05055',
#     'P76010',
#     'P0A796',
#     'P14081',
#     'P39286',
#     'P25522',
#     'P42641',
#     'P0A7I4',
#     'P0A6P5',
#     'P0A705',
#     'P0A6Y8',
#     'P23909',
#     'P69931',
#     'P0A6Z1',
#     'P76014',
#     'P0AF67',
#     'P0A6V1',
#     'P27550',
#     'P69441',
#     'P11454',
#     'P0A6A8',
#     'P0ADI4',
#     'P64604',
#     'P0AFM6',
#     'P10441',
#     'P17993',
#     'P13738',
#     'P45568',
#     'P0ABQ4',
#     'P0AC62',
#     'P75960',
#     'P15042',
#     'P07639',
#     'P09147',
#     'P37329',
#     'P37329',
#     'P0A717',
#     'P0AG82',
#     'P0AFI7',
#     'P16700',
#     'P0AG78',
#     'P16700',
#     'P32662',
#     'P0ACJ8',
#     'P0AFI7',
#     'P0A8V6']),
#   (0.03731333569006755,
#    'hydrolase activity, acting on acid anhydrides',
#    'GO:0016817',
#    ['P65556',
#     'P04079',
#     'P06710',
#     'P0AEI6',
#     'P52061',
#     'P0ABH9',
#     'P0A6F5',
#     'P46889',
#     'P0A9W3',
#     'P0AAG5',
#     'P0A9M0',
#     'P21507',
#     'P37617',
#     'P0A8F8',
#     'P0A698',
#     'P33941',
#     'P43672',
#     'P0A6H1',
#     'P16676',
#     'P52612',
#     'P29018',
#     'P63389',
#     'P06710',
#     'P0A6Y8',
#     'P37624',
#     'P14175',
#     'P0A9U1',
#     'P23909',
#     'P77499',
#     'P23886',
#     'P31473',
#     'Q59385',
#     'P23878',
#     'P25519',
#     'P0AF08',
#     'P0AAI3',
#     'P31548',
#     'P60752',
#     'P60240',
#     'P36879',
#     'P15031',
#     'P77265',
#     'P64612',
#     'P04983',
#     'P0AAG8',
#     'P37774',
#     'P77737',
#     'P31060',
#     'P75957',
#     'P0A9T8',
#     'P64602',
#     'P77279',
#     'P75831',
#     'P0A6Z3',
#     'P76027',
#     'P0A9V1',
#     'P0A6Z1',
#     'P0AEZ3',
#     'P0A6H5',
#     'P0A9U3',
#     'P0ABU2',
#     'P69874',
#     'P0AAH0',
#     'P0AAG3',
#     'P0A9R7',
#     'P0AAF6',
#     'P68187',
#     'P30750',
#     'P63386',
#     'P0AF67',
#     'P07109',
#     'P0AAH8',
#     'P09833',
#     'P15254',
#     'P37624',
#     'P63284',
#     'P0A6Z3',
#     'P63284-2',
#     'P15640',
#     'P0ABH9',
#     'P0A9M0',
#     'P0A6H1',
#     'P0A6G7',
#     'P0AAI3',
#     'P75867',
#     'P43329',
#     'P0AG30',
#     'P08956',
#     'P60240',
#     'P0ACB0',
#     'P09980',
#     'P24230',
#     'P0A812',
#     'P03018',
#     'P07648',
#     'P0ACB0',
#     'P15038',
#     'P46889',
#     'P0A812',
#     'P03018',
#     'P0A8J8',
#     'P0A9P6',
#     'P0A9P6',
#     'P21507',
#     'P43329',
#     'P21499',
#     'P0AES6',
#     'P0AES4',
#     'P24554',
#     'P0A7G6',
#     'P46889',
#     'P03018',
#     'P30958',
#     'P20083',
#     'P0AES6',
#     'P0AFI2',
#     'P0AES4',
#     'P0AES6',
#     'P0AES4',
#     'P0A8H8',
#     'P21507',
#     'P0AG30',
#     'P09372',
#     'P0A6L9',
#     'P52613',
#     'P06974',
#     'P31068',
#     'P0ABZ1',
#     'P15070',
#     'P0A6S0',
#     'P25798',
#     'P23845',
#     'P0A6P5',
#     'P0AGD7',
#     'P0A705',
#     'P14081',
#     'P0A9A6',
#     'P0AAN3',
#     'P60785',
#     'P39286',
#     'P25519',
#     'P24203',
#     'P32132',
#     'P25522',
#     'P42641',
#     'P0CE47',
#     'P0A7I4',
#     'P0A6M8',
#     'P06616',
#     'P10121',
#     'P33030',
#     'P0A8H6',
#     'P0AAI3',
#     'P07024',
#     'P0A7A9',
#     'P0A7A9',
#     'P30871',
#     'P0AFL6',
#     'P0A840',
#     'P0AEY3',
#     'P52061',
#     'P25536',
#     'P0A729',
#     'P75838',
#     'P0AEY3',
#     'P52006',
#     'P52006',
#     'P06968',
#     'P0AFC0',
#     'P08337',
#     'P08337',
#     'P52061',
#     'P52061',
#     'P52061',
#     'P25536',
#     'P25536',
#     'P37128',
#     'P52006',
#     'P25536',
#     'P05637',
#     'P05637',
#     'P43341',
#     'P0AFC0',
#     'P0AEI6',
#     'P0AEI6',
#     'P08337',
#     'P08337',
#     'P06989',
#     'P06282',
#     'Q93K97',
#     'Q93K97',
#     'P45799',
#     'P0A924',
#     'P0A924',
#     'P76445']),
#   (0.04091591066485406,
#    'carbohydrate derivative binding',
#    'GO:0097367',
#    ['P17169',
#     'P0ACS7',
#     'P45395',
#     'P76535',
#     'P46118',
#     'P66817',
#     'P63224',
#     'P0A796',
#     'P0ABH9',
#     'P15038',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P06993',
#     'P0A9C5',
#     'P0A836',
#     'P76085',
#     'P0AF03',
#     'P0A8J8',
#     'P0A6F1',
#     'P0AES0',
#     'P0A6F5',
#     'P00962',
#     'P04805',
#     'P0A9P6',
#     'P0A6A3',
#     'P07363',
#     'P38134',
#     'P0AG20',
#     'P28903',
#     'P21156',
#     'P00968',
#     'P46889',
#     'P69451',
#     'P09980',
#     'P27240',
#     'P15254',
#     'P00959',
#     'P00957',
#     'P10408',
#     'P0ABF1',
#     'P0A9W3',
#     'P0AAG5',
#     'P23845',
#     'P00956',
#     'P0A9M0',
#     'P20083',
#     'P0A8M0',
#     'P0ABB0',
#     'P22523',
#     'P21507',
#     'P0A796',
#     'P37617',
#     'P0A8F8',
#     'P0A698',
#     'P0ABB8',
#     'P04425',
#     'P33941',
#     'P0ABD5',
#     'P0AEW6',
#     'P43672',
#     'P0A6H1',
#     'P24230',
#     'P16676',
#     'P0AES6',
#     'P37773',
#     'P07395',
#     'P03004',
#     'P43329',
#     'P0A812',
#     'P0A8N5',
#     'P0ABA6',
#     'P08622',
#     'P0ABB4',
#     'P0AFI2',
#     'P77718',
#     'P0A9Q5',
#     'P0AG30',
#     'P52612',
#     'P76055',
#     'P03018',
#     'P0AES4',
#     'P0A8M3',
#     'P0A6I6',
#     'P0A7B8',
#     'P29018',
#     'P30958',
#     'P63389',
#     'P0A6E4',
#     'P06710',
#     'P0A817',
#     'P39838',
#     'P00452',
#     'P0A6Y8',
#     'P37624',
#     'P24554',
#     'P0AFA2',
#     'P16384',
#     'P0AEJ4',
#     'P0A6V1',
#     'P11454',
#     'P0A7E9',
#     'P0AE82',
#     'P23331',
#     'P14175',
#     'P60906',
#     'P31663',
#     'P0A9U1',
#     'P45425',
#     'P23909',
#     'P0AD61',
#     'P06961',
#     'P0A894',
#     'P27305',
#     'P21599',
#     'P77499',
#     'P00561',
#     'P13458',
#     'P23886',
#     'P0A6E9',
#     'P31473',
#     'P0AEY3',
#     'P37353',
#     'Q59385',
#     'P76423',
#     'P08956',
#     'P30870',
#     'P0ABH0',
#     'P23837',
#     'P23878',
#     'P0AFB8',
#     'P25519',
#     'P0A8N3',
#     'P0AF08',
#     'P06989',
#     'P07648',
#     'P07604',
#     'P60546',
#     'P0AEC3',
#     'P52097',
#     'P27550',
#     'P0AAI3',
#     'P08660',
#     'P23524',
#     'P31548',
#     'P0A6E6',
#     'P60752',
#     'Q46927',
#     'P0AEC5',
#     'P22106',
#     'P60240',
#     'P0A6J8',
#     'P12282',
#     'P06709',
#     'P0ACB0',
#     'P09029',
#     'P36879',
#     'P13000',
#     'P77756',
#     'P15031',
#     'P77265',
#     'P63284',
#     'P0AD12',
#     'P10378',
#     'P17952',
#     'P08178',
#     'P00562',
#     'P64612',
#     'P04983',
#     'P0A8N7',
#     'P0AAG8',
#     'P37774',
#     'P00963',
#     'P08312',
#     'P77737',
#     'P27278',
#     'P0A7B3',
#     'P77150',
#     'P16456',
#     'P31060',
#     'P0AGG0',
#     'P75957',
#     'P0A8F4',
#     'P04079',
#     'P17115',
#     'P0AG40',
#     'P0A7H0',
#     'P14900',
#     'P0A9T8',
#     'P31802',
#     'P0A717',
#     'P0A8D0',
#     'P77279',
#     'P75831',
#     'P0A6Z3',
#     'P76027',
#     'P22188',
#     'P63284-2',
#     'P75867',
#     'P0A9V1',
#     'P33221',
#     'P23538',
#     'P0A6Z1',
#     'P0AEZ3',
#     'P06999',
#     'P0A6H5',
#     'P0AFU4',
#     'P60757',
#     'P27300',
#     'P0A7D7',
#     'P0AGJ9',
#     'P0A7E5',
#     'P45748',
#     'P62615',
#     'P36928',
#     'P0A9K3',
#     'P0A9U3',
#     'P00954',
#     'P0A6T3',
#     'P0A7B5',
#     'P11880',
#     'P00961',
#     'P0AF28',
#     'P0ADT5',
#     'P15640',
#     'P0ABU2',
#     'P08192',
#     'P69874',
#     'P16659',
#     'P00547',
#     'P77570',
#     'P0A6D7',
#     'P76658',
#     'P0AAH0',
#     'P40191',
#     'P0AAG3',
#     'P46859',
#     'P22259',
#     'P0A9R7',
#     'P18843',
#     'P32099',
#     'P0AAF6',
#     'P37647',
#     'P76014',
#     'P0A6F9',
#     'P0A6I3',
#     'P0A799',
#     'P68187',
#     'P07862',
#     'P24182',
#     'P0C0K3',
#     'P0A7G6',
#     'P0A6V8',
#     'P21888',
#     'P0A6W9',
#     'P0A6F3',
#     'P37903',
#     'P0A9J6',
#     'P0A9H5',
#     'P0AEW9',
#     'P23917',
#     'P75959',
#     'P0A6I0',
#     'P25745',
#     'P00960',
#     'P75745',
#     'P69441',
#     'P0A7Y0',
#     'P30750',
#     'P0A8E7',
#     'P63386',
#     'P0A9X4',
#     'P0AF67',
#     'P07109',
#     'P0A720',
#     'P0A9Z1',
#     'P11875',
#     'P0AAH8',
#     'P0A763',
#     'P0AAV4',
#     'P09833',
#     'P0A6Y8',
#     'P23909',
#     'P69931',
#     'P0A6Z1',
#     'P76014',
#     'P0AF67',
#     'P0A6V1',
#     'P27550',
#     'P69441',
#     'P0ACJ8',
#     'P0A8V6',
#     'P42641',
#     'P0AEZ9',
#     'P0AG20',
#     'P23845',
#     'P22523',
#     'P0A6P5',
#     'P0AGD7',
#     'P0A705',
#     'P0A6T5',
#     'P14081',
#     'P0A9A6',
#     'P0AAN3',
#     'P33650',
#     'P60785',
#     'P76245',
#     'P0A894',
#     'P39286',
#     'P25519',
#     'P24203',
#     'P32132',
#     'P25522',
#     'P42641',
#     'P0A7I7',
#     'P0A7D4',
#     'P0ABU2',
#     'P0CE47',
#     'P0A6P7',
#     'P0A7I4',
#     'P0A6M8',
#     'P06616',
#     'P0A8E7',
#     'P10121',
#     'P0A8F0',
#     'P33030',
#     'P05055',
#     'P76010',
#     'P0A796',
#     'P14081',
#     'P39286',
#     'P25522',
#     'P42641',
#     'P0A7I4',
#     'P0A6P5',
#     'P0A705',
#     'P31979',
#     'P77258',
#     'P38038',
#     'P12008',
#     'P0ABQ0',
#     'P0A7E1',
#     'P33371',
#     'P0ACY1',
#     'P42593',
#     'P77285',
#     'P33232',
#     'P17117',
#     'P13033',
#     'P0AGE6',
#     'P0A9C0',
#     'P0ABY4',
#     'P41407',
#     'P0A8G6',
#     'P65367',
#     'P03817',
#     'P32695',
#     'P61949',
#     'P38489',
#     'P0ACB4',
#     'P0AFI7',
#     'P11557',
#     'P29131',
#     'P10100',
#     'P09549',
#     'P69776',
#     'P0AEU7',
#     'P0ADV1',
#     'P0ADC1',
#     'P0A8V2',
#     'P0ABF6',
#     'P28903',
#     'P28903',
#     'P28903']),
#   (0.04821593263855967,
#    'nucleoside phosphate binding',
#    'GO:1901265',
#    ['P37646',
#     'P0AFG3',
#     'P28248',
#     'P07024',
#     'P0AGE9',
#     'P00968',
#     'P0ADG7',
#     'P09155',
#     'P08331',
#     'P30748',
#     'P68688',
#     'P76491',
#     'P15770',
#     'P0A9M2',
#     'P0A993',
#     'P0A840',
#     'P52061',
#     'P69874',
#     'P39830',
#     'P0AFF6',
#     'P0ACE7',
#     'P0ABH9',
#     'P15038',
#     'P0A8L1',
#     'P21889',
#     'P07813',
#     'P07118',
#     'P06993',
#     'P0A9C5',
#     'P0A836',
#     'P76085',
#     'P0AF03',
#     'P0A8J8',
#     'P0A6F1',
#     'P0AES0',
#     'P0A6F5',
#     'P00962',
#     'P04805',
#     'P0A9P6',
#     'P0A6A3',
#     'P07363',
#     'P38134',
#     'P0AG20',
# ...
#     'P45531',
#     'P45530',
#     'P45532',
#     'P0A6L9',
#     'P0A6Z1',
#     'P0A6P9',
#     'P06959',
#     'P05042',
#     'P0AFG6',
#     'P0A836',
#     'P0AGE9',
#     'P0A7P5',
#     'P0A7N1',
#     'P0A7X6',
#     'P0AFZ3',
#     'P61175',
#     'P60723',
#     'P0A7J3',
#     'P0A7K2',
#     'P61175',
#     'P60723',
#     'P13035',
#     'P0A6S7',
#     'P0A9C0',
#     'P0A6F1',
#     'P00968',
#     'P28903',
#     'P0ABD5',
#     'P0A9Q5',
#     'P0ABD8',
#     'P0AGD7',
#     'P07395',
#     'P08312',
#     'P08142',
#     'P0ADF8',
#     'P35340',
#     'P0AE08',
#     'P0A6R3',
#     'P60595',
#     'P60664',
#     'P0A9D4',
#     'P0ABK5',
#     'P0AA04',
#     'P08839',
#     'P0A8S9',
#     'P05706',
#     'P43533',
#     'P06959',
#     'P06721',
#     'P68066',
#     'P0C058',
#     'P13445',
#     'P0A722',
#     'P00490',
#     'P0A836',
#     'P0A6F1',
#     'P21179',
#     'P07913',
#     'P0AGE9',
#     'P0A9P0',
#     'P07363',
#     'P21513',
#     'P0A8T7',
#     'P39377',
#     'P69451',
#     'P15254',
#     'P28304',
#     'P68767',
#     'P25526',
#     'P0AEN8',
#     'P10408',
#     'P0ABF1',
#     'P0A9W3',
#     'P0A9M0',
#     'P0AGL7',
#     'P0A9J0',
#     'P0A8M0',
#     'P75876',
#     'P06987',
#     'P0A796',
#     'P69797',
#     'P0A8F8',
#     'P0ABT2',
#     'P0AG16',
#     'P0ABD5',
#     'P0A8V2',
#     'P43672',
#     'P0AG67',
#     'P0AES6',
#     'P37773',
#     'Q46939',
#     'P21645',
#     'P0A6Q6',
#     'P08622',
#     'P0AFI2',
#     'P52612',
#     'P09372',
#     'P0AES4',
#     'P0A6T5',
#     'P17854',
#     'P25516',
#     'P75864',
#     'P0A8M3',
#     'P0A6I6',
#     'P0ABS1',
#     'P31992',
#     'P09155',
#     'P23522',
#     'P14081',
#     'P36659',
#     'P0A9A6',
#     'P0AED5',
#     'P00582',
#     'P04391',
#     'P76273',
#     'P21338',
#     'P13001',
#     'P0A6Y8',
#     'P0A9G2',
#     'P0A9F6',
#     'P12995',
#     'P52129',
#     'P67826',
#     'P0A9F1',
#     'P13024',
#     'P0A9W0',
#     'P43341',
#     'P25746',
#     'P10443',
#     'P0A881',
#     'P0AGG4',
#     'P75682',
#     'P60716',
#     'P0A8U0',
#     'P05458',
#     'P0A7Z4',
#     'P0A6E9',
#     'P31473',
#     ...]),
#   (1.0,
#    'cell',
#    'GO:0005623',
#    ['P68688',
#     'P75936',
#     'P0A9A2',
#     'P75937',
#     'P26608',
#     'P0ABH9',
#     'P0ACY9',
#     'P0C054',
#     'P0AGK8',
#     'P09373',
#     'P52643',
#     'P04982',
#     'P0AFP6',
#     'P0A9G6',
#     'P0A759',
#     'Q46938',
#     'P0AFG3',
#     'P68066',
#     'P0AC38',
#     'P15038',
#     'P0AEM6',
#     'P28248',
#     'P0A8L1',
#     'P0A9S3',
#     'P0AFG6',
#     'P64599',
#     'P0A794',
#     'P0AET8',
#     'P17445',
#     'P21889',
#     'P07004',
#     'P12758',
#     'P33570',
#     'P07813',
#     'P27302',
#     'P0A7S3',
#     'P0A9B2',
#     'P0A722',
#     'P07118',
#     'P0AG07',
#     'P0ABP8',
#     'P0A853',
#     'P0ABD3',
#     'P69922',
#     'P0ABU0',
#     'P0A7J0',
#     'P0A9C5',
#     'P76187',
#     'P0ACE3',
#     'P25553',
#     'P0AB80',
#     'P18133',
#     'P0AGK4',
#     'P60651',
#     'P00490',
#     'P0A9H9',
#     'P22256',
#     'P0A836',
#     'P75829',
#     'P0AGG2',
#     'P0AF03',
#     'P0AG24',
#     'P0AEU7',
#     'P0A8J8',
#     'P15034',
#     'P0AEZ9',
#     'P0A6F1',
#     'P33195',
#     'P0AES0',
#     'P21179',
#     'P0A9H7',
#     'P0A6L4',
#     'P77258',
#     'P0A6F5',
#     'P00962',
#     'P07913',
#     'P07003',
#     'P76558',
#     'P69908',
#     'P0AGE9',
#     'P32176',
#     'P24186',
#     'P0ADK8',
#     'P04805',
#     'P07364',
#     'P0A9P6',
#     'P0A9P0',
#     'P31057',
#     'P0A6A3',
#     'P02359',
#     'P21499',
#     'P60340',
#     'P07363',
#     'P0A8T7',
#     'P09831',
#     'P0ACB2',
#     'P30850',
#     'P0ADW3',
#     'P0A7U3',
#     'P23830',
#     'P13029',
#     'P00968',
#     'P0AGJ5',
#     'P39377',
#     'P69451',
#     'P0ACD4',
#     'P06612',
#     'P0A9Q7',
#     'P15254',
#     'P60422',
#     'P09832',
#     'P28304',
#     'P0A7A9',
#     'P0A7K6',
#     'P00959',
#     'P00957',
#     'P67910',
#     'P0A998',
#     'P0ACC7',
#     'P0A832',
#     'P10408',
#     'P0ABF1',
#     'P0AG18',
#     'P0A968',
#     'P0AD33',
#     'P60438',
#     'P0A9E5',
#     'P0A6B7',
#     'P05055',
#     'P0A7V3',
#     'P21367',
#     'P00956',
#     'P37095',
#     'P04036',
#     'P0A9M0',
#     'P75913',
#     'P20083',
#     'P0A7M2',
#     'P0ACP7',
#     'P25524',
#     'P68679',
#     'P22523',
#     'P21507',
#     'P75876',
#     'P0A796',
#     'P46853',
#     'P17169',
#     'P0AD49',
#     'P0ADY3',
#     'P0AA39',
#     'P12008',
#     'P64588',
#     'P37188',
#     'P0AAQ2',
#     'P69797',
#     'P0ADG7',
#     'P33643',
#     'Q57261',
#     'P05791',
#     'P0A698',
#     'P05793',
#     'P0A6T1',
#     'P75823',
#     'P0AAB4',
#     'P26616',
#     'P04425',
#     'P00350',
#     'P0AG16',
#     'P77488',
#     'P77433',
#     'P0AFG8',
#     'P0A6P5',
#     'P46837',
#     'P0A7V8',
#     'P15639',
#     'P0ABD5',
#     'P0AGD7',
#     'P0A6U3',
#     'P0A7S9',
#     'P0A8V2',
#     'P0AG27',
#     'P0A6H1',
#     'P24230',
#     'P0AES6',
#     'P0AEI1',
#     'P07395',
#     'P03004',
#     'P69786',
#     'P0AG55',
#     'P0A812',
#     'P0A746',
#     'P0A7L0',
#     'P18390',
#     'P0A7L3',
#     'P0A7R9',
#     'P05459',
#     'P0A8N5',
#     'P21645',
#     'P0ABH7',
#     'P08622',
#     'P0AEK4',
#     'P0AFI2',
#     'P0A847',
#     'P77718',
#     'P0A9Q5',
#     'P0AG30',
#     'P0A8H6',
#     'P76055',
#     'P0A7X3',
#     'P09372',
#     'P0A705',
#     'P03018',
#     'P0ADT8',
#     'P0A8R0',
#     'P21169',
#     'P0AES4',
#     'P76403',
#     'P37666',
#     'P0A6T5',
#     'P0A7W1',
#     'P75838',
#     'P31828',
#     'P0AA10',
#     'P63177',
#     'P25516',
#     'P0A964',
#     'P61175',
#     'P0A6X3',
#     'P0AAC8',
#     'P0AEJ6',
#     'P0A6G7',
#     'P09151',
#     'P0A953',
#     'P0A8M3',
#     'P03023',
#     'P0A7B8',
#     'P76034',
#     'P0ABS1',
#     'P14407',
#     'P30958',
#     'P60624',
#     'P37051',
#     'P00582',
#     'P26602',
#     'P0A6A6',
#     'P0AG48',
#     'P29745',
#     'P0A6E4',
#     'P0A7U7',
#     'P0A817',
#     'P00452',
#     'P60785',
#     'P31068',
#     'P0A6Y8',
#     'P37692',
#     'P35340',
#     'P0A9P4',
#     'P0ABQ0',
#     'P0A9B6',
#     'P33940',
#     'P11454',
#     'P0A7E9',
#     'P00579',
#     'P23331',
#     'P36979',
#     'P62623',
#     'P0AGE0',
#     'P60906',
#     'P31663',
#     'P13024',
#     'P0ADQ7',
#     'P0A744',
#     'P10443',
#     'P23909',
#     'P23839',
#     'P0AD61',
#     'P0A6L2',
#     'P0AGG4',
#     'P0A988',
#     'P15288',
#     'P29680',
#     'P30748',
#     'P0AAI5',
#     'P0AG86',
#     'Q46893',
#     'P21599',
#     'P0AG44',
#     'P0AC53',
#     'P60716',
#     'P77499',
#     'P37765',
#     'P17993',
#     'P0A7E1',
#     'P0A7Z4',
#     'P36929',
#     'P30125',
#     'P0A6S7',
#     'P0A8J4',
#     'P31473',
#     'P0A8I3',
#     'P00363',
#     'P0A7C2',
#     'P0AB71',
#     'P76423',
#     'P0A7T7',
#     'P0C018',
#     'P08956',
#     'P30870',
#     'P0AF90',
#     'P39286',
#     'P65556',
#     'P0A9M8',
#     'P0ABH0',
#     'P0A6R3',
#     'P0AGG8',
#     'P0AAI9',
#     'P68206',
#     'P36683',
#     'P08957',
#     'P0AC33',
#     'P30178',
#     'P62620',
#     'P0AFB8',
#     'P25519',
#     'P60723',
#     'P0ADI7',
#     'P0A8N3',
#     'P0ADR8',
#     'P0AF08',
#     'P06989',
#     'P00864',
#     'P04693',
#     'P0AC47',
#     'P06988',
#     'P21165',
#     'P21829',
#     'P0A790',
#     'P0AC62',
#     'P27859',
#     'P07604',
#     'P0ACY1',
#     'P0A8U6',
#     'P60546',
#     'P0A6Y1',
#     'P52097',
#     'P76316',
#     'P0A884',
#     'P69913',
#     'P27550',
#     'P29217',
#     'P16095',
#     'P36767',
#     'P0ADG4',
#     'P69924',
#     'P69828',
#     'P64506',
#     'P0ADP9',
#     'P08660',
#     'P39315',
#     'P0A800',
#     'P0A7N9',
#     'P64624',
#     'P0A6A8',
#     'P0ACP5',
#     'P22106',
#     'P25738',
#     'P0AAZ7',
#     'P0AB58',
#     'P0A6K1',
#     'P0A7X6',
#     'P0ACC3',
#     'P0A6J8',
#     'P06992',
#     'P76290',
#     'P69506',
#     'P12282',
#     'P37330',
#     'P0ACB0',
#     'P24203',
#     'P0A877',
#     'P0ADI4',
#     'P0AF96',
#     'P0AFZ3',
#     'P77735',
#     'P17117',
#     'P24178',
#     'P0A715',
#     'P09029',
#     'P0A8A0',
#     'P0AE12',
#     'P13000',
#     'P0A8T1',
#     'P0AE52',
#     'P45578',
#     'P0A8X0',
#     'P0A9R4',
#     'P27838',
#     'P63284',
#     'P0ADZ4',
#     'P10371',
#     'P52007',
#     'P13033',
#     'P0ADN2',
#     'P0AD12',
#     'P75914',
#     'P0ACR9',
#     'P0ACQ4',
#     'P0AB61',
#     'P0AFM6',
#     'P10378',
#     'P0A9Q9',
#     'P64554',
#     'P67080',
#     'P08178',
#     'P69829',
#     'P15047',
#     'P0A6Y5',
#     'P00562',
#     'P0AEM0',
#     'P60664',
#     'Q46856',
#     'P63020',
#     'P61517',
#     'P0AB14',
#     'P69503',
#     'P0A8N7',
#     'P0A879',
#     'P0AA25',
#     'P0AGE6',
#     'P0AFX0',
#     'P0A784',
#     'P0A9W9',
#     'P0A9C0',
#     'P0A6L9',
#     'P00963',
#     'P75874',
#     'P0AB77',
#     'P0ADS2',
#     'P08312',
#     'P0AE67',
#     'P45577',
#     'P0A6U5',
#     'P0ABD8',
#     'P64534',
#     'P07650',
#     'P0A734',
#     'P76569',
#     'P0A9K9',
#     'P0A6R0',
#     'P18196',
#     'P69783',
#     'P52697',
#     'P0A8W8',
#     'P15770',
#     'P13009',
#     'P0A7F9',
#     'P09148',
#     'P0AFJ1',
#     'P0A9T4',
#     'P69795',
#     'P0A7B3',
#     'P0AF93',
#     'P32157',
#     'P15042',
#     'P77150',
#     'P0AD24',
#     'P0A9I3',
#     'P16456',
#     'P75849',
#     'P77695',
#     'P67603',
#     'P37689',
#     'Q46857',
#     'P0A9D4',
#     'P77252',
#     'P0AEP3',
#     'P0A8E1',
#     'P0ADE8',
#     'P23003',
#     'P0A962',
#     'P27298',
#     'P0AC81',
#     'P0A8F4',
#     'P04079',
#     'P32132',
#     'P00509',
#     'P0A6N8',
#     'P41407',
#     'Q46868',
#     'P75949',
#     'P0A9S5',
#     'Q46871',
#     'P0A731',
#     'P0AA04',
#     'P06986',
#     'P10441',
#     'P0A7H0',
#     'P30011',
#     'P25397',
#     'P0A8B5',
#     'P05194',
#     'P0AFU8',
#     'P60472',
#     'P0A825',
#     'Q93K97',
#     'P0A867',
#     'P28904',
#     'P76015',
#     'P09158',
#     'P64602',
#     'P0A717',
#     'P0AB91',
#     'P0A6W5',
#     'P0A9S1',
#     'P0A8G6',
#     'P0AB55',
#     'P0A9M2',
#     'P0ACN4',
#     'P0AEI4',
#     'P0AFQ7',
#     'P0ACX3',
#     'P08179',
#     'P0DMC7',
#     'P37747',
#     'P0ADU2',
#     'P07012',
#     'P39173',
#     'P27848',
#     'P0A873',
#     'P37349',
#     'P27127',
#     'P0AA43',
#     'P0A6Z3',
#     'P25522',
#     'P0A972',
#     'P0A6X7',
#     'P0ACZ4',
#     'P0ACJ0',
#     'P77395',
#     'P60560',
#     'P22188',
#     'P63284-2',
#     'P0A9G8',
#     'P0ABU5',
#     'P0A7J7',
#     'P08390',
#     'P31142',
#     'P03817',
#     'P69931',
#     'P31120',
#     'P0A993',
#     'P0AD57',
#     'P63417',
#     'P23869',
#     'P30177',
#     'P33221',
#     'P23538',
#     'P76008',
#     'P0A6Z1',
#     'P0AEZ3',
#     'P06999',
#     'P69428',
#     'P61714',
#     'P0A7I0',
#     'P27829',
#     'P0A6H5',
#     'P06983',
#     'P0AEY5',
#     'P25906',
#     'P0AB89',
#     'P08373',
#     'P0A8C4',
#     'P60757',
#     'P23882',
#     'P42641',
#     'P0A7D7',
#     'P08244',
#     'P31433',
#     'P0AGJ9',
#     'P0A805',
#     'P37745',
#     'P0ABE2',
#     'P0A7E5',
#     'P45748',
#     'P0AEH5',
#     'P32695',
#     'P24171',
#     'P0C0R7',
#     'P39356',
#     'P22333',
#     'P40874',
#     'P04951',
#     'P00946',
#     'P36680',
#     'P0A9K3',
#     'P0AED7',
#     'P00954',
#     'P0ABF6',
#     'P0A6T3',
#     'P0A7B5',
#     'P11880',
#     'P0AFK0',
#     'P0ABC7',
#     'P00961',
#     'P37744',
#     'P06968',
#     'P0AAR3',
#     'P36938',
#     'P0AEN1',
#     'P0A7D4',
#     'P0ACF0',
#     'P0AF28',
#     'P76270',
#     'P27306',
#     'P05020',
#     'P51024',
#     'P0ACI0',
#     'P61949',
#     'P52061',
#     'P0C0L2',
#     'P0C0L9',
#     'P09053',
#     'P25437',
#     'P33644',
#     'P00934',
#     'P23721',
#     'P0AC92',
#     'P09147',
#     'P38489',
#     'P30014',
#     'P0A8W5',
#     'P00926',
#     'Q46829',
#     'P0AC13',
#     'P27828',
#     'P16659',
#     'P0A6P9',
#     'P00547',
#     'P69222',
#     'P0A6D7',
#     'P0AF36',
#     'P0A9T0',
#     'P76658',
#     'P0ACF4',
#     'P0A6D3',
#     'P40191',
#     'P31658',
#     'P22259',
#     'P0A707',
#     'P32680',
#     'P37005',
#     'P18843',
#     'P32099',
#     'P37760',
#     'P0A890',
#     'P0A8M6',
#     'P0ACB4',
#     'P0A8Y5',
#     'P37647',
#     'P09424',
#     'P0A6Q3',
#     'P76014',
#     'P0A8P3',
#     'P28861',
#     'P0A6F9',
#     'P0A6P7',
#     'P0A978',
#     'P77247',
#     'P0A6K6',
#     'P0A858',
#     'P0A799',
#     'P07862',
#     'P75915',
#     'P69228',
#     'P0A7I4',
#     'P62707',
#     'P63224',
#     'P0A9Y6',
#     'P0A8A2',
#     'P0A761',
#     'P24182',
#     'P0A862',
#     'P31475',
#     'P08839',
#     'P0A9D8',
#     'P0A6V8',
#     'P0A9N4',
#     'P21888',
#     'P0A6W9',
#     'P0A9L3',
#     'P0A6F3',
#     'P0A7F6',
#     'P64455',
#     'P0A9J6',
#     'P37759',
#     'P23893',
#     'P0A870',
#     'P0AC19',
#     'P22939',
#     'P0A9F3',
#     'P0AFF6',
#     'P0ADV5',
#     'P23917',
#     'P76256',
#     'P0A850',
#     'P76268',
#     'P0ACA1',
#     'P0C037',
#     'P0A7Z0',
#     'P0A6I0',
#     'P0A780',
#     'P0A955',
#     'P0A749',
#     'P75736',
#     'P0AE01',
#     'P25745',
#     'P00960',
#     'P12281',
#     'P0AF24',
#     'P05852',
#     'P08200',
#     'P0AAB6',
#     'Q46920',
#     'P32662',
#     'P0ABQ4',
#     'P75745',
#     'P0A7W7',
#     'P69441',
#     'P0AE48',
#     'P0A7Y0',
#     'P0ACJ8',
#     'P0AE88',
#     'P0A9W6',
#     'P0A6M8',
#     'P06616',
#     'P39199',
#     'P0A6L0',
#     'P0A8E7',
#     'P09030',
#     'P0A6P1',
#     'P00448',
#     'P67095',
#     'P76536',
#     'P0AAT6',
#     'P0ACA3',
#     'P23836',
#     'P0AF12',
#     'P0AE18',
#     'Q46948',
#     'P0A7J3',
#     'P0A7R5',
#     'P0A8A8',
#     'P0A9M5',
#     'P0A9X9',
#     'P0ACA7',
#     'P61889',
#     'P0ACE7',
#     'P0A6N4',
#     'P10121',
#     'P0AFR4',
#     'P0AAB8',
#     'P0A720',
#     'P0AE08',
#     'P0AFY8',
#     'P0AFG0',
#     'P0A9A9',
#     'P0ABK5',
#     'P0AGD3',
#     'P38521',
#     'P0A9Z1',
#     'P0AEB7',
#     'P0AFI7',
#     'P0A7R1',
#     'P0A8F0',
#     'P11875',
#     'P0A8V6',
#     'P0A7N4',
#     'P0ABZ4',
#     'P0AC59',
#     'P0A763',
#     'P27248',
#     'P0A9Q1',
#     'P39831',
#     'P0AB52',
#     'P0AB28',
#     'P0AEK2',
#     'P60390',
#     'P0A7M9',
#     'P02358',
#     'P0AC69',
#     'P68919',
#     'P0ACG1',
#     'P45799',
#     'P0A6K3',
#     'P0ACF8',
#     'P0A7K2',
#     'P0A7G2',
#     'P0A9L8',
#     'P62399',
#     'P0A7S3',
#     'P02359',
#     'P0A7U3',
#     'P0A7V3',
#     'P68679',
#     'P0AD49',
#     'P0A7V8',
#     'P0A7S9',
#     'P0AG67',
#     'P0A7R9',
#     'P0A7X3',
#     'P0A7W1',
#     'P0AG59',
#     'P0A7U7',
#     'P37624',
#     'P0A7T7',
#     'P0AG63',
#     'P0ADZ4',
#     'P0A7V0',
#     'P0A7W7',
#     'P0A7R5',
#     'P0A7T3',
#     'P02358',
#     'P0A7Q6',
#     'P60422',
#     'P0A7K6',
#     'P60438',
#     'P0A7M2',
#     'P0ADY3',
#     'P0A7L8',
#     'P0ADY7',
#     'P0AG55',
#     'P0A7L0',
#     'P0A7L3',
#     'P0AA10',
#     'P61175',
#     'P60624',
#     'P0AG48',
#     'P02413',
#     'P0AG44',
#     'P0C018',
#     'P0ADZ0',
#     'P60723',
#     'P0A7N9',
#     'P0A7J7',
#     'P0A7J3',
#     'P0AG51',
#     'P0A7R1',
#     'P0A7N4',
#     'P0A7M6',
#     'P0A7M9',
#     'P68919',
#     'P0A7K2',
#     'P62399',
#     'P0A6F5',
#     'P0A6F9',
#     'P0A796',
#     'P0A6H1',
#     'P0A6G7',
#     'P0A7B8',
#     'P0AFZ3',
#     'P0A6H5',
#     'P00452',
#     'P69924',
#     'P45531',
#     'P45530',
#     'P45532',
#     'P0A6L9',
#     'P0A6Z1',
#     'P0A6P9',
#     'P06959',
#     'P05042',
#     'P0AFG6',
#     'P0A836',
#     'P0AGE9',
#     'P0A7P5',
#     'P0A7N1',
#     'P0A7X6',
#     'P0AFZ3',
#     'P61175',
#     'P60723',
#     'P0A7J3',
#     'P0A7K2',
#     'P61175',
#     'P60723',
#     'P13035',
#     'P0A6S7',
#     'P0A9C0',
#     'P0A6F1',
#     'P00968',
#     'P28903',
#     'P0ABD5',
#     'P0A9Q5',
#     'P0ABD8',
#     'P0AGD7',
#     'P07395',
#     'P08312',
#     'P08142',
#     'P0ADF8',
#     'P35340',
#     'P0AE08',
#     'P0A6R3',
#     'P60595',
#     'P60664',
#     'P0A9D4',
#     'P0ABK5',
#     'P0AA04',
#     'P08839',
#     'P0A8S9',
#     'P05706',
#     'P43533',
#     'P06959',
#     'P06721',
#     'P68066',
#     'P0C058',
#     'P13445',
#     'P0A722',
#     'P00490',
#     'P0A836',
#     'P0A6F1',
#     'P21179',
#     'P07913',
#     'P0AGE9',
#     'P0A9P0',
#     'P07363',
#     'P21513',
#     'P0A8T7',
#     'P39377',
#     'P69451',
#     'P15254',
#     'P28304',
#     'P68767',
#     'P25526',
#     'P0AEN8',
#     'P10408',
#     'P0ABF1',
#     'P0A9W3',
#     'P0A9M0',
#     'P0AGL7',
#     'P0A9J0',
#     'P0A8M0',
#     'P75876',
#     'P06987',
#     'P0A796',
#     'P69797',
#     'P0A8F8',
#     'P0ABT2',
#     'P0AG16',
#     'P0ABD5',
#     'P0A8V2',
#     'P43672',
#     'P0AG67',
#     'P0AES6',
#     'P37773',
#     'Q46939',
#     'P21645',
#     'P0A6Q6',
#     'P08622',
#     'P0AFI2',
#     'P52612',
#     'P09372',
#     'P0AES4',
#     'P0A6T5',
#     'P17854',
#     'P25516',
#     'P75864',
#     'P0A8M3',
#     'P0A6I6',
#     'P0ABS1',
#     'P31992',
#     'P09155',
#     'P23522',
#     'P14081',
#     'P36659',
#     'P0A9A6',
#     'P0AED5',
#     'P00582',
#     'P04391',
#     'P76273',
#     'P21338',
#     'P13001',
#     'P0A6Y8',
#     'P0A9G2',
#     'P0A9F6',
#     'P12995',
#     'P52129',
#     'P67826',
#     'P0A9F1',
#     'P13024',
#     'P0A9W0',
#     'P43341',
#     'P25746',
#     'P10443',
#     'P0A881',
#     'P0AGG4',
#     'P75682',
#     'P60716',
#     'P0A8U0',
#     'P05458',
#     'P0A7Z4',
#     'P0A6E9',
#     ...])]}

# %%
import json
json_file = json.dumps(GO_term)
# Out:
# '{"biological_process": [[0.9999999999342061, "bacterial-type flagellum-dependent cell motility", "GO:0071973", ["P29744"]], [0.9999999999698048, "archaeal or bacterial-type flagellum-dependent cell motility", "GO:0097588", ["P29744"]], [0.9999999999862025, "phosphoenolpyruvate-dependent sugar phosphotransferase system", "GO:0009401", ["P05706"]], [0.9999999999883546, "cell motility", "GO:0048870", ["P29744"]], [0.9999999999942798, "localization", "GO:0051179", ["P29744", "P05706"]], [1.0, "biological_process", "GO:0008150", ["P29744", "P05706"]]], "molecular_function": [[7.601006048565208e-05, "identical protein binding", "GO:0042802", ["P0C054", "P0AGK8", "P04982", "P0AFP6", "P0A759", "Q46938", "P0AFG3", "P0C058", "P0A8L1", "P0A9S3", "P0A794", "P0AET8", "P17445", "P07004", "P12758", "P0A722", "P06993", "P0ABP8", "P0AC16", "P0A853", "P0ABD3", "P69922", "P0A7J0", "P0A9C5", "P04128", "P25553", "P0AB80", "P0A9H9", "P0AGG2", "P0AF03", "P0AEU7", "P15034", "P0AEZ9", "P33195", "P21179", "P0AEE3", "P0A6L4", "P0A6F5", "P07003", "P0A9P0", "P31057", "P38134", "P21513", "P0ABU7", "P13029", "P46889", "P39377", "P0ABV2", "P0ACD4", "P0A9Q7", "P00957", "P0A998", "P0ACC7", "P10408", "P0AG18", "P05055", "P21367", "P37095", "P04036", "P00805", "P25524", "P22523", "P06987", "P0A796", "P12008", "P0ADG7", "P0A8F8", "P0A698", "P05793", "P0A6T1", "P75823", "P0AAB4", "P0AES9", "P0ABT2", "P00350", "P50466", "P0AG16", "P0A6X1", "P0AFG8", "P0ABD5", "P0A6H1", "P37773", "P07395", "P03004", "P0AFL6", "P76291", "P21645", "P0A6Q6", "P0ABH7", "P0AEK4", "P0AG30", "P52612", "P0AES4", "P04825", "P05707", "P06136", "P0A6G7", "P0A6I6", "P03023", "P0A7B8", "P0A9A6", "P31069", "P33650", "P0A6E4", "P06710", "P0A817", "P31224", "P00452", "P60785", "P77791", "P0AEJ4", "P0A6V1", "P0A7E9", "P0AE82", "P0AGE0", "P31663", "P23909", "P0AD61", "P0A6L2", "P0A988", "P0A894", "Q46893", "P0ADV9", "P37194", "P21599", "P75682", "P0A8J2", "P0AC53", "P31473", "P37353", "P0ABZ1", "P0A951", "P0ACU0", "P0A7C2", "P0AB71", "P76423", "P0AE06", "P45568", "P76491", "P69425", "P0ABH0", "P39099", "P23837", "P0AC33", "P09546", "P03024", "P0AFX9", "P0C093", "P0A742", "P60546", "P52097", "P0A6S5", "P0C0S1", "P69924", "P50456", "P19624", "P60752", "P22106", "P0ADA1", "P0ACB0", "P24203", "P0ADI4", "P63284", "P0AFM6", "P15047", "P0A6Y5", "P69503", "P0A879", "P0A9W9", "P40710", "P00963", "P0ADS2", "P0A734", "P39376", "P18196", "P0AF93", "P77150", "P33025", "P0AC51", "P69423", "P0AEP3", "P0A962", "P04079", "P00509", "P0A9S5", "P06986", "P14900", "P05194", "P0A825", "P76541", "P76015", "P0AB91", "P0A8G6", "P0ACN4", "P43671", "P0A873", "P75831", "P0C0V0", "P0A6Z3", "P25522", "P0ACJ0", "P60560", "P63284-2", "P69931", "P0AD57", "P0AEZ3", "P06999", "P69428", "P0A6H5", "P0ADV1", "P0A7E5", "P0ADY1", "P0AB10", "P36680", "P0AED7", "P0ABF6", "P0A7B5", "P37744", "P00887", "P0ACF0", "P27306", "P25437", "P66817", "P65870", "P0AC92", "P09147", "P38489", "P30014", "P27828", "P0A6P9", "P0AF36", "P0A9T0", "P0ACF4", "P77804", "P0A6F9", "P0A858", "P69228", "P27303", "P25536", "P08839", "P69776", "P27833", "P0A9L3", "P0A6F3", "P37759", "P23893", "P0A9F3", "P76256", "P0A850", "P0A7Z0", "P0A955", "P33920", "P12281", "P05852", "P0A6D0", "P0ACJ8", "P67095", "P23836", "P0AF12", "P62617", "P0A9X4", "P0AF67", "P0ACA7", "P0AE08", "P0AFY8", "P0ABK5", "P0A9Z1", "P0A8F0", "P0AED0", "P0A9Q1", "P0AB52", "P0AFJ5", "P0AEK2", "P0A903", "P77774", "P0ACF8", "P0A937", "P0A9L8", "P0A910", "P02930", "P02931", "P00350", "P0AFG8", "P09372", "P0A6E4", "P0AE70", "P0A6R3", "P0A9K7", "P06709", "P0AFZ3", "P05704", "P0A8I8", "P07017", "P52061", "P33644", "P02942", "P0AFI7", "P0A921", "P0A7K2"]], [0.00012670434614784154, "protein binding", "GO:0005515", ["P0ABR1", "P0A8R0", "P0AF90", "P0AB38", "P0A7Y0", "P0AFW4", "P0A6W5", "P30128", "P30958", "P13445", "P60240", "P0AFF6", "P0AFW0", "P21513", "P0A6H1", "P0A6G7", "P0AFZ3", "P07017", "P02942", "P0A6P1", "P0C054", "P0AGK8", "P04982", "P0AFP6", "P0A759", "Q46938", "P0AFG3", "P0C058", "P0A8L1", "P0A9S3", " ...

# %% [markdown]
# ## Une première application: représentation riche du résultat de l'analyse
#
#
# ### Mise en forme "riche" des résultats grâce au notebook
#
# Jupyter permet d'étendre le concept de la méthode **__str__()** afin de produire du contenu HTML.
#  Ainsi, tout objet impémentant une méthode **_repr_html_()** sera affiché, via son rendu HTML, dans la cellule d'un notebook.
#
# ```python
# class Point():
#     def __init__(self, x, y, z):
#         self.x = x
#         self.y = y
#         self.z = z
#     def _repr_html_(self):
#         htmlString = "<table><thead><tr><td>Abscisse</td><td>Ordonnée</td><td>Cote</td></tr></thead>"
#         htmlString += f"<tbody><tr><td>{self.x}</td><td>{self.y}</td><td>{self.z}</td></tr></tbody></table>"
#         return htmlString
# Point(2,3,4)
# ```
# Affichera
#
# ![caption](../figs/reprhtml.png)
#
#
# ### Intégration des résultats à la visualisation du notebook
#
# En vous inspirant de la fonction ci-dessus, implémenter une classe Rich_GO_ORA dont la méthode [`_repr_html_`](https://ipython.readthedocs.io/en/stable/config/integrating.html) permettra un affichage plus lisible d'une des analyses `biological_process / molecular_function /cellular_component`
#
# Un exemple possible est,
# ![caption](../figs/_repr_html_.png)
#
# (Bonus): clicker sur le nom du terme GO envoie vers sa description.
# Pour cela, afficher le nom du pathway dans une balise hyperlien pour permettre d'acceder à la page de description du terme GO.
#
# Les termes GO sont accessibles aux URL de la forme
# `http://amigo.geneontology.org/amigo/term/GO:GO_NUMBER`.

# %%
class Rich_GO_ORA():
    def __init__(self,x):
        self.x = x
    def _repr_html_(self):
        htmlString = "<table><thead><tr><td><b>p-value</b></td><td><b>Pathway name</b></td><td><b>n</b></td></tr></thead>"
        for i,j in enumerate(self.x):
            list_x = j
            htmlString += f"<tbody><tr><td>{list_x[0]}</td><td><a href='http://amigo.geneontology.org/amigo/term/{list_x[2]}'>{list_x[1]}</a></td><td>{len(list_x[3])}</td></tr></tbody>"
        htmlString += "</table>"
        return htmlString

# %%
Rich_GO_ORA(GO_term['biological_process'])
# Out:
# <table><thead><tr><td><b>p-value</b></td><td><b>Pathway name</b></td><td><b>n</b></td></tr></thead><tbody><tr><td>0.9999999999342061</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0071973'>bacterial-type flagellum-dependent cell motility</a></td><td>1</td></tr></tbody><tbody><tr><td>0.9999999999698048</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0097588'>archaeal or bacterial-type flagellum-dependent cell motility</a></td><td>1</td></tr></tbody><tbody><tr><td>0.9999999999862025</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0009401'>phosphoenolpyruvate-dependent sugar phosphotransferase system</a></td><td>1</td></tr></tbody><tbody><tr><td>0.9999999999883546</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0048870'>cell motility</a></td><td>1</td></tr></tbody><tbody><tr><td>0.9999999999942798</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0051179'>localization</a></td><td>2</td></tr></tbody><tbody><tr><td>1.0</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0008150'>biological_process</a></td><td>2</td></tr></tbody></table>

# %%
Rich_GO_ORA(GO_term["molecular_function"])
# Out:
# <table><thead><tr><td><b>p-value</b></td><td><b>Pathway name</b></td><td><b>n</b></td></tr></thead><tbody><tr><td>7.601006048565208e-05</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0042802'>identical protein binding</a></td><td>299</td></tr></tbody><tbody><tr><td>0.00012670434614784154</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0005515'>protein binding</a></td><td>383</td></tr></tbody><tbody><tr><td>0.0010681967228459621</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0003723'>RNA binding</a></td><td>180</td></tr></tbody><tbody><tr><td>0.0036742641741427783</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0003735'>structural constituent of ribosome</a></td><td>54</td></tr></tbody><tbody><tr><td>0.005092043899540847</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0019843'>rRNA binding</a></td><td>55</td></tr></tbody><tbody><tr><td>0.007216465321729826</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0005198'>structural molecule activity</a></td><td>62</td></tr></tbody><tbody><tr><td>0.014170159359436718</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0016874'>ligase activity</a></td><td>98</td></tr></tbody><tbody><tr><td>0.016708954119011427</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0000287'>magnesium ion binding</a></td><td>126</td></tr></tbody><tbody><tr><td>0.0198163054027285</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0016879'>ligase activity, forming carbon-nitrogen bonds</a></td><td>47</td></tr></tbody><tbody><tr><td>0.02027625815747051</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0004812'>aminoacyl-tRNA ligase activity</a></td><td>29</td></tr></tbody><tbody><tr><td>0.026020259113962805</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0140101'>catalytic activity, acting on a tRNA</a></td><td>72</td></tr></tbody><tbody><tr><td>0.02845134212783707</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0036094'>small molecule binding</a></td><td>576</td></tr></tbody><tbody><tr><td>0.03221843391232357</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0016462'>pyrophosphatase activity</a></td><td>194</td></tr></tbody><tbody><tr><td>0.03283803789191233</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0043168'>anion binding</a></td><td>503</td></tr></tbody><tbody><tr><td>0.03731333569006755</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0016817'>hydrolase activity, acting on acid anhydrides</a></td><td>195</td></tr></tbody><tbody><tr><td>0.04091591066485406</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0097367'>carbohydrate derivative binding</a></td><td>375</td></tr></tbody><tbody><tr><td>0.04821593263855967</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:1901265'>nucleoside phosphate binding</a></td><td>480</td></tr></tbody><tbody><tr><td>0.04821593263855967</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0000166'>nucleotide binding</a></td><td>480</td></tr></tbody><tbody><tr><td>0.05144374798320214</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0000049'>tRNA binding</a></td><td>34</td></tr></tbody><tbody><tr><td>0.05286816739390626</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0032553'>ribonucleotide binding</a></td><td>355</td></tr></tbody><tbody><tr><td>0.0569075545777231</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0140098'>catalytic activity, acting on RNA</a></td><td>142</td></tr></tbody><tbody><tr><td>0.06395315166295044</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0030554'>adenyl nucleotide binding</a></td><td>287</td></tr></tbody><tbody><tr><td>0.06567585994052333</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0032559'>adenyl ribonucleotide binding</a></td><td>285</td></tr></tbody><tbody><tr><td>0.07084151551949715</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0008144'>drug binding</a></td ...

# %%
Rich_GO_ORA(GO_term["cellular_component"])
# Out:
# <table><thead><tr><td><b>p-value</b></td><td><b>Pathway name</b></td><td><b>n</b></td></tr></thead><tbody><tr><td>1.1683447768867192e-17</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0005829'>cytosol</a></td><td>868</td></tr></tbody><tbody><tr><td>1.38569935135936e-17</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0044444'>cytoplasmic part</a></td><td>906</td></tr></tbody><tbody><tr><td>1.3467787831600082e-08</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0005737'>cytoplasm</a></td><td>1143</td></tr></tbody><tbody><tr><td>4.007337369464756e-08</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0044424'>intracellular part</a></td><td>1209</td></tr></tbody><tbody><tr><td>0.00865638993000764</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0044445'>cytosolic part</a></td><td>70</td></tr></tbody><tbody><tr><td>0.010392906973042643</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:1990904'>ribonucleoprotein complex</a></td><td>66</td></tr></tbody><tbody><tr><td>0.010990358302520353</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0005840'>ribosome</a></td><td>64</td></tr></tbody><tbody><tr><td>0.011030986885737826</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0022626'>cytosolic ribosome</a></td><td>54</td></tr></tbody><tbody><tr><td>0.011030986885737826</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0044391'>ribosomal subunit</a></td><td>58</td></tr></tbody><tbody><tr><td>0.017546752412052995</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0043229'>intracellular organelle</a></td><td>87</td></tr></tbody><tbody><tr><td>0.018449984884957058</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0043232'>intracellular non-membrane-bounded organelle</a></td><td>86</td></tr></tbody><tbody><tr><td>0.023969444036545724</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0043226'>organelle</a></td><td>108</td></tr></tbody><tbody><tr><td>0.025065562658815</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0043228'>non-membrane-bounded organelle</a></td><td>107</td></tr></tbody><tbody><tr><td>0.03166250010985615</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0044446'>intracellular organelle part</a></td><td>64</td></tr></tbody><tbody><tr><td>0.04396514497458757</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0022625'>cytosolic large ribosomal subunit</a></td><td>31</td></tr></tbody><tbody><tr><td>0.04396514497458757</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0015934'>large ribosomal subunit</a></td><td>35</td></tr></tbody><tbody><tr><td>0.045803687885356215</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0044422'>organelle part</a></td><td>83</td></tr></tbody><tbody><tr><td>0.07482737917747485</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0022627'>cytosolic small ribosomal subunit</a></td><td>23</td></tr></tbody><tbody><tr><td>0.1262948230290126</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0009898'>cytoplasmic side of plasma membrane</a></td><td>22</td></tr></tbody><tbody><tr><td>0.14621004273420152</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0019897'>extrinsic component of plasma membrane</a></td><td>17</td></tr></tbody><tbody><tr><td>0.16493892069572746</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0098552'>side of membrane</a></td><td>48</td></tr></tbody><tbody><tr><td>0.17047363489684514</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0009295'>nucleoid</a></td><td>15</td></tr></tbody><tbody><tr><td>0.19381576140220994</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0098561'>methyl accepting chemotaxis protein complex</a></td><td>7</td></tr></tbody><tbody><tr><td>0.20535559024143202</td><td><a href='http://amigo.geneontology.org/amigo/term/GO:0019898'>extrinsic component of membrane</a></td><td>19</td></tr></tbody><tbody><tr><td>0.23399505648 ...

# %% [markdown]
# ## Une deuxième application: volcano plot améliorés
# ###### PANDAS
# En choisissant comme seuil la valeur `alpha` du TP précédent, veuillez extraires les identifiants uniprot des protéines sur-abondantes (rappel les valeurs d'abondance sont celles de la colonne `Log2 Corrected Abundance Ratio`).
#
# Vous devrez avoir dans des listes distinctes:
# * identifiants uniprot
# * `Log2 Corrected Abundance Ratio`
# * `LOG10 Adj.P-val'`
#
# ###### Représentation graphiques
# * Pour la catégorie de termes GO (biological_process / molecular_function /cellular_component) de votre choix
#     * Générer une grille de 4 graphiques
#     * Dans chaque graphique colorez dans une couleur différentes les protéines porteuses de 4 termes de GO que vous estimez les plus pertinents
#     * Donnez le nom de la catégorie générale à la grille
#     * Donnez le nom du terme GO représenté dans chaque graphique avec une couleur de titre cohérente.

# %%
alpha = -0.0993349420002988
data_id = data[data["Log2 Corrected Abundance Ratio"] > alpha]

GO_term2= {
    "biological_process" : [],
    "molecular_function" : [],
    "cellular_component" : []
}
list_prot = []
for prot in data_id["Accession"]:
        list_prot += {prot}
GO_term2["biological_process"] = o.biological_process(list_prot)
GO_term2["molecular_function"] = o.molecular_function(list_prot)
GO_term2["cellular_component"] = o.cellular_component(list_prot)

list_id = data_id["Accession"]
list_log2 = data_id["Log2 Corrected Abundance Ratio"]
list_log10 = data_id["LOG10 Adj.P-val"]
data_id
# Out:
# Evaluated 0 / 7 Pathways, based on 67 proteins
# Evaluated 229 / 1691 Pathways, based on 67 proteins
# Evaluated 63 / 208 Pathways, based on 67 proteins
#      Accession                                        Description Gene Symbol  \
# 1902    P39831  NADP-dependent 3-hydroxy acid dehydrogenase Yd...        ydfG
# 1904    P0AG78  Sulfate-binding protein OS=Escherichia coli (s...         sbp
# 1905    P0A9H1  G/U mismatch-specific DNA glycosylase OS=Esche...         mug
# 1906    P60955  Prolipoprotein diacylglyceryl transferase OS=E...         lgt
# 1910    P0AB52  Protein YchN OS=Escherichia coli (strain K12) ...        ychN
# ...        ...                                                ...         ...
# 2011    P77330  Prophage lipoprotein Bor homolog OS=Escherichi...        borD
# 2016    P02930  Outer membrane protein TolC OS=Escherichia col...        tolC
# 2020    P0A917  Outer membrane protein X OS=Escherichia coli (...        ompX
# 2021    P02931  Outer membrane protein F OS=Escherichia coli (...        ompF
# 2022    P0AB40  Multiple stress resistance protein BhsA OS=Esc...        bhsA
#
#       Corrected Abundance ratio (1.53)  Log2 Corrected Abundance Ratio  \
# 1902                          0.937908                       -0.092481
# 1904                          0.939869                       -0.089468
# 1905                          0.942484                       -0.085460
# 1906                          0.943791                       -0.083461
# 1910                          0.949673                       -0.074497
# ...                                ...                             ...
# 2011                          1.535948                        0.619129
# 2016                          1.552288                        0.634396
# 2020                          1.579739                        0.659686
# 2021                          1.754902                        0.811390
# 2022                          1.798039                        0.846424
#
#       Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)  \
# 1902                                           1.000000
# 1904                                           1.000000
# 1905                                           1.000000
# 1906                                           1.000000
# 1910                                           1.000000
# ...                                                 ...
# 2011                                           0.310725
# 2016                                           0.013373
# 2020                                           0.002226
# 2021                                           0.000068
# 2022                                           0.035928
#
#       LOG10 Adj.P-val
# 1902         0.000000
# 1904         0.000000
# 1905         0.000000
# 1906         0.000000
# 1910         0.000000
# ...               ...
# 2011         0.507623
# 2016         1.873757
# 2020         2.652391
# 2021         4.164956
# 2022         1.444561
#
# [67 rows x 7 columns]

# %%
# from collections import Counter
list_go = {}
for i,j in enumerate(GO_term2["molecular_function"]):
    list_go[j[1]] = j[0]

list_go
sorted(list_go.items(), key=lambda x: x[1])
# Out:
# [('porin activity', 1.1519075123216585e-06),
#  ('channel activity', 2.2463488413563718e-06),
#  ('structural molecule activity', 0.00020347570292712273),
#  ('structural constituent of ribosome', 0.00029279132188945463),
#  ('protein domain specific binding', 0.00034817734327016335),
#  ('signaling receptor activity', 0.0006757861606550164),
#  ('protein N-terminus binding', 0.001291951807567506),
#  ('molecular transducer activity', 0.0013276908407484403),
#  ('5S rRNA binding', 0.00254875677898479),
#  ('protein binding, bridging', 0.00254875677898479),
#  ('colicin transmembrane transporter activity', 0.00254875677898479),
#  ('bacteriocin transmembrane transporter activity', 0.00254875677898479),
#  ('ion channel activity', 0.00410716064639805),
#  ('rRNA binding', 0.008538986001505029),
#  ('ligand-gated channel activity', 0.008562622102456691),
#  ('inorganic molecular entity transmembrane transporter activity',
#   0.0088318926775539),
#  ('ion transmembrane transporter activity', 0.013843045558671163),
#  ('protein dimerization activity', 0.014005572461032005),
#  ('protein binding', 0.014081538653569557),
#  ('ATPase-coupled inorganic anion transmembrane transporter activity',
#   0.014284849503975783),
#  ('virus receptor activity', 0.021042713567812888),
#  ('3-oxoacyl-[acyl-carrier-protein] reductase (NADPH) activity',
#   0.021042713567812888),
#  ('phosphatidylglycerol-prolipoprotein diacylglyceryl transferase activity',
#   0.021042713567812888),
#  ('rRNA (cytosine-N4-)-methyltransferase activity', 0.021042713567812888),
#  ('protein-L-isoaspartate (D-aspartate) O-methyltransferase activity',
#   0.021042713567812888),
#  ('pyrimidine-specific mismatch base pair DNA N-glycosylase activity',
#   0.021042713567812888),
#  ('1-acyl-2-lysophosphatidylserine acylhydrolase activity',
#   0.021042713567812888),
#  ('phosphatidylserine 1-acylhydrolase activity', 0.021042713567812888),
#  ('phospholipase A1 activity', 0.021042713567812888),
#  ('phospholipase A2 activity', 0.021042713567812888),
#  ('phospholipase A2 activity (consuming 1,2-dipalmitoylphosphatidylcholine)',
#   0.021042713567812888),
#  ('phospholipase A2 activity consuming 1,2-dioleoylphosphatidylethanolamine)',
#   0.021042713567812888),
#  ('peptide deformylase activity', 0.021042713567812888),
#  ('serine 3-dehydrogenase activity', 0.021042713567812888),
#  ('3-oxo-glutaryl-[acp] methyl ester reductase activity',
#   0.021042713567812888),
#  ('3-oxo-pimeloyl-[acp] methyl ester reductase activity',
#   0.021042713567812888),
#  ('pyrroline-5-carboxylate reductase activity', 0.021042713567812888),
#  ('maltodextrin transmembrane transporter activity', 0.021042713567812888),
#  ('glutamate:sodium symporter activity', 0.021042713567812888),
#  ('molybdenum ion transmembrane transporter activity', 0.021042713567812888),
#  ('long-chain fatty acid transporting porin activity', 0.021042713567812888),
#  ('sodium:dicarboxylate symporter activity', 0.021042713567812888),
#  ('nucleoside-specific channel forming porin activity', 0.021042713567812888),
#  ('fatty acid transmembrane transporter activity', 0.021042713567812888),
#  ('iron ion binding', 0.026647869852056652),
#  ('gated channel activity', 0.029319032184396045),
#  ('cadmium ion binding', 0.04164910319710912),
#  ('sulfate binding', 0.04164910319710912),
#  ('virion binding', 0.04164910319710912),
#  ('protein carboxyl O-methyltransferase activity', 0.04164910319710912),
#  ('ADP-sugar diphosphatase activity', 0.04164910319710912),
#  ('3-hydroxypropionate dehydrogenase (NADP+) activity', 0.04164910319710912),
#  ('D-ribose transmembrane transporter activity', 0.04164910319710912),
#  ('maltose transporting porin activity', 0.04164910319710912),
#  ('ATPase-coupled molybdate transmembrane transporter activity',
#   0.04164910319710912),
#  ('ferric iron transmembrane transporter activity', 0.04164910319710912),
#  ('transmembrane transporter activity', 0.04367049981401075),
#  ('transporter activity', 0.04660053118495686),
#  ('ATPase-coupled ion transmembrane transporter activity',
#   0.05067400371981445),
#  ('ribonucleoprotein complex binding', 0.05717199302094118),
#  ('four-way junction DNA binding', 0.06182808185450619),
#  ('bacterial-type RNA polymerase holo enzyme binding', 0.06182808185450619),
#  ('polysaccharide transmembrane transporter activity', 0.06182808185450619),
#  ('ATPase-coupled transmembrane transporter activity', 0.06619297090831237),
#  ('protein-containing complex binding', 0.07504171282696573),
#  ('bent DNA binding', 0.08158838317903941),
#  ('disordered domain specific binding', 0.08158838317903941),
#  ('organic acid:sodium symporter activity', 0.08158838317903941),
#  ('amino acid:sodium symporter activity', 0.08158838317903941),
#  ('ATPase-coupled vitamin B12 transmembrane transporter activity',
#   0.08158838317903941),
#  ('identical protein binding', 0.08633669640022226),
#  ('primary active transmembrane transporter activity', 0.08947186011673594),
#  ('anion transmembrane transporter activity', 0.09025333959076137),
#  ('RNA binding', 0.09203689078080074),
#  ('metal ion transmembrane transporter activity', 0.09507903663722453),
#  ('protein homodimerization activity', 0.09605666779523726),
#  ('ribosome binding', 0.09605666779523726),
#  ('xenobiotic transmembrane transporter activity', 0.09605666779523726),
#  ("mRNA 5'-UTR binding", 0.10093856504259224),
#  ('toxic substance binding', 0.10093856504259224),
#  ('phospholipase activity', 0.10093856504259224),
#  ('maltose transmembrane transporter activity', 0.10093856504259224),
#  ('ATPase-coupled sulfate transmembrane transporter activity',
#   0.10093856504259224),
#  ('amino acid:cation symporter activity', 0.10093856504259224),
#  ('ferric-enterobactin transmembrane transporter activity',
#   0.10093856504259224),
#  ('transition metal ion transmembrane transporter activity',
#   0.10269475074258516),
#  ('peptide transmembrane transporter activity', 0.10269475074258516),
#  ('inorganic anion transmembrane transporter activity', 0.10945621750630358),
#  ('small ribosomal subunit rRNA binding', 0.11988701302719917),
#  ('rRNA (cytosine) methyltransferase activity', 0.11988701302719917),
#  ('solute:sodium symporter activity', 0.11988701302719917),
#  ('iron ion transmembrane transporter activity', 0.11988701302719917),
#  ('fatty acid synthase activity', 0.13844194384141334),
#  ('protein methyltransferase activity', 0.13844194384141334),
#  ('aspartic-type endopeptidase activity', 0.13844194384141334),
#  ('sulfate transmembrane transporter activity', 0.13844194384141334),
#  ('DNA N-glycosylase activity', 0.1566114086706347),
#  ('disaccharide transmembrane transporter activity', 0.1566114086706347),
#  ('pyrophosphate hydrolysis-driven proton transmembrane transporter activity',
#   0.1566114086706347),
#  ('proton-transporting ATP synthase activity, rotational mechanism',
#   0.1566114086706347),
#  ('ATPase activity, coupled to transmembrane movement of ions, rotational mechanism',
#   0.1566114086706347),
#  ('dicarboxylic acid transmembrane transporter activity', 0.1566114086706347),
#  ('siderophore transmembrane transporter activity', 0.1566114086706347),
#  ('vitamin transmembrane transporter activity', 0.1566114086706347),
#  ('lipid transporter activity', 0.1566114086706347),
#  ('O-methyltransferase activity', 0.17440329646043995),
#  ('oligosaccharide transmembrane transporter activity', 0.17440329646043995),
#  ('nucleoside transmembrane transporter activity', 0.17440329646043995),
#  ('inorganic cation transmembrane transporter activity', 0.17851760018025709),
#  ('aromatic amino acid transmembrane transporter activity',
#   0.1918253371330435),
#  ('active ion transmembrane transporter activity', 0.19999985372798185),
#  ('carboxylic acid transmembrane transporter activity', 0.20872406975981905),
#  ('ribosomal small subunit binding', 0.20888510474783734),
#  ('organic acid transmembrane transporter activity', 0.21424283174765393),
#  ('transition metal ion binding', 0.21767968149826644),
#  ('zinc ion binding', 0.2223474117160043),
#  ('calcium ion binding', 0.22559002059489985),
#  ('oxidoreductase activity, acting on the CH-NH group of donors, NAD or NADP as acceptor',
#   0.22559002059489985),
#  ('sodium ion transmembrane transporter activity', 0.22559002059489985),
#  ('phosphorelay response regulator activity', 0.22559002059489985),
#  ('endopeptidase activity', 0.24440951978105302),
#  ('metalloendopeptidase activity', 0.25796423643292105),
#  ('oxidoreductase activity, acting on the CH-NH group of donors',
#   0.25796423643292105),
#  ('organic anion transmembrane transporter activity', 0.25940884946081283),
#  ('serine-type endopeptidase activity', 0.27364764216041243),
#  ('S-adenosylmethionine-dependent methyltransferase activity',
#   0.28381237458853675),
#  ('amino acid transmembrane transporter activity', 0.28381237458853675),
#  ('mRNA binding', 0.28900441337330784),
#  ('protein disulfide oxidoreductase activity', 0.28900441337330784),
#  ('hydrolase activity, hydrolyzing N-glycosyl compounds', 0.304041251852396),
#  ('macromolecule transmembrane transporter activity', 0.304041251852396),
#  ('N-methyltransferase activity', 0.3187647239469714),
#  ('ATPase-coupled cation transmembrane transporter activity',
#   0.3331812632717426),
#  ('monocarboxylic acid transmembrane transporter activity',
#   0.3331812632717426),
#  ('ferrous iron binding', 0.34729717333679777),
#  ('active transmembrane transporter activity', 0.3634774592459556),
#  ('disulfide oxidoreductase activity', 0.3746516847845192),
#  ('cation transmembrane transporter activity', 0.3797762537679159),
#  ('methyltransferase activity', 0.3846978627368296),
#  ('rRNA methyltransferase activity', 0.38790226578145975),
#  ('sulfur compound transmembrane transporter activity', 0.40087618169656436),
#  ('efflux transmembrane transporter activity', 0.40087618169656436),
#  ('DNA-binding transcription repressor activity', 0.40087618169656436),
#  ('GTPase activity', 0.41357912341114983),
#  ('monosaccharide transmembrane transporter activity', 0.4260166665360454),
#  ('carbohydrate derivative transmembrane transporter activity',
#   0.4260166665360454),
#  ('symporter activity', 0.42937753639060905),
#  ('endodeoxyribonuclease activity', 0.46179097892147297),
#  ('carboxylic ester hydrolase activity', 0.4732204573424432),
#  ('monovalent inorganic cation transmembrane transporter activity',
#   0.4793347088177543),
#  ('oxidoreductase activity, acting on the CH-OH group of donors, NAD or NADP as acceptor',
#   0.4999408430687925),
#  ('NADP binding', 0.5060934883448311),
#  ('2 iron, 2 sulfur cluster binding', 0.5060934883448311),
#  ('transferase activity, transferring one-carbon groups', 0.5066962010300992),
#  ('RNA methyltransferase activity', 0.5268774051601394),
#  ('carbohydrate transmembrane transporter activity', 0.5331341073283118),
#  ('sulfur compound binding', 0.5467992316940252),
#  ('serine-type peptidase activity', 0.5467992316940252),
#  ('hydrolase activity, acting on carbon-nitrogen (but not peptide) bonds, in linear amides',
#   0.5467992316940252),
#  ('metallopeptidase activity', 0.5751422474918544),
#  ('oxidoreductase activity, acting on CH-OH group of donors',
#   0.577084608501369),
#  ('tRNA binding', 0.5841961499773464),
#  ('deoxyribonuclease activity', 0.5841961499773464),
#  ('oxidoreductase activity, acting on a sulfur group of donors',
#   0.5841961499773464),
#  ('solute:cation symporter activity', 0.6102327701111658),
#  ('catalytic activity, acting on a protein', 0.6245383078818947),
#  ('peptidase activity, acting on L-amino acid peptides', 0.6400328275830649),
#  ('NAD binding', 0.6575812726040919),
#  ('transcription regulatory region sequence-specific DNA binding',
#   0.6859502390442742),
#  ('peptidase activity', 0.6859886763373193),
#  ('secondary active transmembrane transporter activity', 0.7048517206857665),
#  ('sequence-specific double-stranded DNA binding', 0.7056952071009208),
#  ('transcription regulatory region DNA binding', 0.7056952071009208),
#  ('GTP binding', 0.7056952071009208),
#  ('hydrolase activity, acting on glycosyl bonds', 0.7120010661100715),
#  ('purine ribonucleoside binding', 0.7181737879861362),
#  ('proton transmembrane transporter activity', 0.7181737879861362),
#  ('ribonucleoside binding', 0.7242161419659643),
#  ('nucleoside binding', 0.7359205407714294),
#  ('guanyl ribonucleotide binding', 0.7471353023368793),
#  ('guanyl nucleotide binding', 0.7525654096297514),
#  ('transferase activity, transferring acyl groups other than amino-acyl groups',
#   0.7525654096297514),
#  ('endonuclease activity', 0.7525654096297514),
#  ('metal ion binding', 0.7604156678354586),
#  ('double-stranded DNA binding', 0.7731605028265068),
#  ('cation binding', 0.7765915699162861),
#  ('hydrolase activity, acting on carbon-nitrogen (but not peptide) bonds',
#   0.7780395546108956),
#  ('transferase activity, transferring glycosyl groups', 0.8052163011821283),
#  ('electron transfer activity', 0.836412714579694),
#  ('catalytic activity, acting on DNA', 0.8413879355424865),
#  ('pyrophosphatase activity', 0.8554853039891205),
#  ('hydrolase activity, acting on acid anhydrides', 0.8618476076738916),
#  ('nuclease activity', 0.8626753555967925),
#  ('transferase activity, transferring acyl groups', 0.8656510189765572),
#  ('nucleoside-triphosphatase activity', 0.9186994338074573),
#  ('sequence-specific DNA binding', 0.9207576175524169),
#  ('nucleic acid binding', 0.957377967190391),
#  ('iron-sulfur cluster binding', 0.9601792998854262),
#  ('catalytic activity, acting on RNA', 0.9601792998854262),
#  ('hydrolase activity, acting on ester bonds', 0.9641628631477009),
#  ('ATPase activity', 0.9666968129373217),
#  ('hydrolase activity', 0.9716872278674791),
#  ('magnesium ion binding', 0.9787422538542107),
#  ('DNA-binding transcription factor activity', 0.9851885962487381),
#  ('oxidoreductase activity', 0.9862162164709789),
#  ('binding', 0.989851765613559),
#  ('transcription regulator activity', 0.9899321871467623),
#  ('DNA binding', 0.9924211264224769),
#  ('coenzyme binding', 0.9972221703524891),
#  ('cofactor binding', 0.9974524489770425),
#  ('ion binding', 0.9986776566753093),
#  ('transferase activity', 0.9997323690848965),
#  ('purine ribonucleoside triphosphate binding', 0.9998261573378817),
#  ('purine ribonucleotide binding', 0.9998618385561923),
#  ('purine nucleotide binding', 0.999864985805479),
#  ('ribonucleotide binding', 0.9999373327893671),
#  ('ATP binding', 0.999956930073969),
#  ('adenyl ribonucleotide binding', 0.9999609857505496),
#  ('adenyl nucleotide binding', 0.9999619393997355),
#  ('carbohydrate derivative binding', 0.9999644481862627),
#  ('nucleoside phosphate binding', 0.9999876822180285),
#  ('nucleotide binding', 0.9999876822180285),
#  ('anion binding', 0.9999936983390029),
#  ('drug binding', 0.9999957351920391),
#  ('organic cyclic compound binding', 0.9999970582796047),
#  ('heterocyclic compound binding', 0.9999970582796047),
#  ('small molecule binding', 0.999999231228997),
#  ('catalytic activity', 0.9999999999942404),
#  ('molecular_function', 1.0)]

# %%
accession = pd.Series.tolist(data_id["Accession"])

# %%
fig1, ((ax1, ax2),(ax3, ax4)) = plt.subplots(dpi=200, ncols=2, nrows=2)
x = data_id["Log2 Corrected Abundance Ratio"]
y = data_id["LOG10 Adj.P-val"]

ax1.scatter(x,y)
ax2.scatter(x,y)
ax3.scatter(x,y)
ax4.scatter(x,y)

prot_porin_activity = GO_term2["molecular_function"][0][3]
for i in [i for i in prot_porin_activity if i in accession] :
    pts = data_id[data_id["Accession"] == i]
    x1 = [i for i in pts["Log2 Corrected Abundance Ratio"]]
    y1 = [i for i in pts["LOG10 Adj.P-val"]]
    ax1.scatter(x1,y1, color="red")
ax1.set_title("porin activity")

channel_activity = GO_term2["molecular_function"][1][3]
for i in [i for i in channel_activity if i in accession] :
    pts = data_id[data_id["Accession"] == i]
    x1 = [i for i in pts["Log2 Corrected Abundance Ratio"]]
    y1 = [i for i in pts["LOG10 Adj.P-val"]]
    ax2.scatter(x1,y1, color="green")
ax2.set_title("channel activity")

structural_activity = GO_term2["molecular_function"][2][3]
for i in [i for i in structural_activity if i in accession] :
    pts = data_id[data_id["Accession"] == i]
    x1 = [i for i in pts["Log2 Corrected Abundance Ratio"]]
    y1 = [i for i in pts["LOG10 Adj.P-val"]]
    ax3.scatter(x1,y1, color="orange")
ax3.set_title("structural activity")


domain_binding = GO_term2["molecular_function"][4][3]
for i in [i for i in domain_binding if i in accession] :
    pts = data_id[data_id["Accession"] == i]
    x1 = [i for i in pts["Log2 Corrected Abundance Ratio"]]
    y1 = [i for i in pts["LOG10 Adj.P-val"]]
    ax4.scatter(x1,y1, color="purple")
ax4.set_title("domain binding")
plt.tight_layout()
plt.show()
